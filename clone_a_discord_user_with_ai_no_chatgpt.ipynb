# %% [markdown]
# # Fine-tune a DialoGPT model
#
# Adapted from the notebook in [this Medium post](https://towardsdatascience.com/make-your-own-rick-sanchez-bot-with-transformers-and-dialogpt-fine-tuning-f85e6d1f4e30?gi=e4a72d1510f0).

# %% [markdown]
# ## Setup

# %%
# !pip -q install transformers

# %%
# all the imports
import csv
import glob
import requests
import json
import logging
import os
import csv
import pickle
import random
import re
import shutil
from typing import Dict, List, Tuple

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset, RandomSampler, SequentialSampler
from torch.utils.data.distributed import DistributedSampler
from tqdm.notebook import tqdm, trange

from pathlib import Path

from transformers import (
    MODEL_WITH_LM_HEAD_MAPPING,
    WEIGHTS_NAME,
    AdamW,
    AutoConfig,
    PreTrainedModel,
    PreTrainedTokenizer,
    get_linear_schedule_with_warmup,
)


try:
    from torch.utils.tensorboard import SummaryWriter
except ImportError:
    from tensorboardX import SummaryWriter

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir("/content/drive/My Drive/")

# %% [markdown]
# ## Get Data

# %%
# Input CSV file
input_file = "your csv file here"

# Output file
output_file = "output.csv"

# Extract content from each column
with open(input_file, 'r', encoding='utf-8') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')

    # Assuming you want to extract the second and fourth columns
    extracted_data = [(row[1], row[3]) for row in csv_reader]

# Write the extracted content to the output file
with open(output_file, 'w', newline='', encoding='utf-8') as csv_output:
    csv_writer = csv.writer(csv_output)
    csv_writer.writerows(extracted_data)

print(f"Content extracted and saved to {output_file}")
# Out:
# Content extracted and saved to output.csv

# %%
data = pd.read_csv('output.csv', sep=',', error_bad_lines=False, quoting=csv.QUOTE_NONE)
# Out:
# <ipython-input-8-b791c42cce77>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv('output.csv', sep=',', error_bad_lines=False, quoting=csv.QUOTE_NONE)
# Skipping line 18: expected 2 fields, saw 3
# Skipping line 25: expected 2 fields, saw 3
# Skipping line 30: expected 2 fields, saw 4
# Skipping line 31: expected 2 fields, saw 4
# Skipping line 33: expected 2 fields, saw 6
# Skipping line 35: expected 2 fields, saw 3
# Skipping line 38: expected 2 fields, saw 3
# Skipping line 55: expected 2 fields, saw 4
# Skipping line 56: expected 2 fields, saw 3
# Skipping line 59: expected 2 fields, saw 3
# Skipping line 62: expected 2 fields, saw 5
# Skipping line 64: expected 2 fields, saw 3
# Skipping line 70: expected 2 fields, saw 3
# Skipping line 76: expected 2 fields, saw 3
# Skipping line 77: expected 2 fields, saw 3
# Skipping line 82: expected 2 fields, saw 3
# Skipping line 83: expected 2 fields, saw 3
# Skipping line 84: expected 2 fields, saw 3
# Skipping line 85: expected 2 fields, saw 3
# Skipping line 88: expected 2 fields, saw 3
# Skipping line 91: expected 2 fields, saw 3
# Skipping line 93: expected 2 fields, saw 3
# Skipping line 98: expected 2 fields, saw 3
# Skipping line 113: expected 2 fields, saw 3
# Skipping line 121: expected 2 fields, saw 3
# Skipping line 128: expected 2 fields, saw 3
# Skipping line 133: expected 2 fields, saw 7
# Skipping line 140: expected 2 fields, saw 4
# Skipping line 145: expected 2 fields, saw 5
# Skipping line 150: expected 2 fields, saw 3
# Skipping line 151: expected 2 fields, saw 4
# Skipping line 154: expected 2 fields, saw 3
# Skipping line 168: expected 2 fields, saw 4
# Skipping line 176: expected 2 fields, saw 3
# Skipping line 178: expected 2 fields, saw 3
# Skipping line 187: expected 2 fields, saw 4
# Skipping line 189: expected 2 fields, saw 3
# Skipping line 194: expected 2 fields, saw 3
# Skipping line 195: expected 2 fields, saw 3
# Skipping line 197: expected 2 fields, saw 3
# Skipping line 202: expected 2 fields, saw 4
# Skipping line 204: expected 2 fields, saw 3
# Skipping line 212: expected 2 fields, saw 3
# Skipping line 213: expected 2 fields, saw 3
# Skipping line 217: expected 2 fields, saw 8
# Skipping line 218: expected 2 fields, saw 3
# Skipping line 220: expected 2 fields, saw 3
# Skipping line 224: expected 2 fields, saw 3
# Skipping line 226: expected 2 fields, saw 3
# Skipping line 231: expected 2 fields, saw 3
# Skipping line 232: expected 2 fields, saw 3
# Skipping line 238: expected 2 fields, saw 3
# Skipping line 244: expected 2 fields, saw 3
# Skipping line 249: expected 2 fields, saw 3
# Skipping line 251: expected 2 fields, saw 3
# Skipping line 252: expected 2 fields, saw 7
# Skipping line 253: expected 2 fields, saw 4
# Skipping line 257: expected 2 fields, saw 3
# Skipping line 285: expected 2 fields, saw 3
# Skipping line 294: expected 2 fields, saw 3
# Skipping line 298: expected 2 fields, saw 3
# Skipping line 299: expected 2 fields, saw 3
# Skipping line 300: expected 2 fields, saw 3
# Skipping line 303: expected 2 fields, saw 3
# Skipping line 304: expected 2 fields, saw 3
# Skipping line 306: expected 2 fields, saw 3
# Skipping line 321: expected 2 fields, saw 3
# Skipping line 325: expected 2 fields, saw 4
# Skipping line 343: expected 2 fields, saw 3
# Skipping line 345: expected 2 fields, saw 3
# Skipping line 349: expected 2 fields, saw 3
# Skipping line 350: expected 2 fields, saw 3
# Skipping line 353: expected 2 fields, saw 3
# Skipping line 390: expected 2 fields, saw 3
# Skipping line 396: expected 2 fields, saw 4
# Skipping line 408: expected 2 fields, saw 4
# Skipping line 410: expected 2 fields, saw 3
# Skipping line 414: expected 2 fields, saw 3
# Skipping line 416: expected 2 fields, saw 5
# Skipping line 420: expected 2 fields, saw 6
# Skipping line 421: expected 2 fields, saw 3
# Skipping line 432: expected 2 fields, saw 3
# Skipping line 433: expected 2 fields, saw 3
# Skipping line 434: expected 2 fields, saw 3
# Skipping line 435: expected 2 fields, saw 3
# Skipping line 442: expected 2 fields, saw 4
# Skipping line 443: expected 2 fields, saw 4
# Skipping line 446: expected 2 fields, saw 4
# Skipping line 449: expected 2 fields, saw 4
# Skipping line 453: expected 2 fields, saw 3
# Skipping line 455: expected 2 fields, saw 3
# Skipping line 456: expected 2 fields, saw 7
# Skipping line 458: expected 2 fields, saw 4
# Skipping line 489: expected 2 fields, saw 3
# Skipping line 494: expected 2 fields, saw 6
# Skipping line 498: expected 2 fields, saw 3
# Skipping line 500: expected 2 fields, saw 6
# Skipping line 504: expected 2 fields, saw 3
# Skipping line 507: expected 2 fields, saw 4
# Skipping line 509: expected 2 fields, saw 3
# Skipping line 511: expected 2 fields, saw 3
# Skipping line 512: expected 2 fields, saw 5
# Skipping line 517: expected 2 fields, saw 3
# Skipping line 523: expected 2 fields, saw 3
# Skipping line 529: expected 2 fields, saw 3
# Skipping line 530: expected 2 fields, saw 3
# Skipping line 547: expected 2 fields, saw 3
# Skipping line 553: expected 2 fields, saw 3
# Skipping line 563: expected 2 fields, saw 3
# Skipping line 567: expected 2 fields, saw 3
# Skipping line 572: expected 2 fields, saw 3
# Skipping line 577: expected 2 fields, saw 3
# Skipping line 581: expected 2 fields, saw 3
# Skipping line 591: expected 2 fields, saw 4
# Skipping line 625: expected 2 fields, saw 4
# Skipping line 638: expected 2 fields, saw 3
# Skipping line 639: expected 2 fields, saw 3
# Skipping line 656: expected 2 fields, saw 3
# Skipping line 663: expected 2 fields, saw 4
# Skipping line 667: expected 2 fields, saw 3
# Skipping line 668: expected 2 fields, saw 3
# Skipping line 672: expected 2 fields, saw 4
# Skipping line 673: expected 2 fields, saw 3
# Skipping line 674: expected 2 fields, saw 3
# Skipping line 688: expected 2 fields, saw 3
# Skipping line 693: expected 2 fields, saw 3
# Skipping line 708: expected 2 fields, saw 4
# Skipping line 715: expected 2 fields, saw 3
# Skipping line 725: expected 2 fields, saw 3
# Skipping line 735: expected 2 fields, saw 3
# Skipping line 752: expected 2 fields, saw 3
# Skipping line 765: expected 2 fields, saw 3
# Skipping line 767: expected 2 fields, saw 3
# Skipping line 777: expected 2 fields, saw 4
# Skipping line 782: expected 2 fields, saw 3
# Skipping line 791: expected 2 fields, saw 3
# Skipping line 792: expected 2 fields, saw 3
# Skipping line 820: expected 2 fields, saw 3
# Skipping line 823: expected 2 fields, saw 3
# Skipping line 827: expected 2 fields, saw 4
# Skipping line 842: expected 2 fields, saw 3
# Skipping line 844: expected 2 fields, saw 3
# Skipping line 846: expected 2 fields, saw 4
# Skipping line 847: expected 2 fields, saw 3
# Skipping line 848: expected 2 fields, saw 4
# Skipping line 851: expected 2 fields, saw 4
# Skipping line 860: expected 2 fields, saw 3
# Skipping line 861: expected 2 fields, saw 3
# Skipping line 865: expected 2 fields, saw 4
# Skipping line 869: expected 2 fields, saw 5
# Skipping line 871: expected 2 fields, saw 3
# Skipping line 877: expected 2 fields, saw 3
# Skipping line 895: expected 2 fields, saw 3
# Skipping line 896: expected 2 fields, saw 3
# Skipping line 897: expected 2 fields, saw 3
# Skipping line 898: expected 2 fields, saw 3
# Skipping line 908: expected 2 fields, saw 3
# Skipping line 911: expected 2 fields, saw 3
# Skipping line 919: expected 2 fields, saw 4
# Skipping line 921: expected 2 fields, saw 4
# Skipping line 931: expected 2 fields, saw 3
# Skipping line 950: expected 2 fields, saw 3
# Skipping line 961: expected 2 fields, saw 3
# Skipping line 998: expected 2 fields, saw 3
# Skipping line 999: expected 2 fields, saw 4
# Skipping line 1006: expected 2 fields, saw 3
# Skipping line 1009: expected 2 fields, saw 3
# Skipping line 1011: expected 2 fields, saw 3
# Skipping line 1014: expected 2 fields, saw 3
# Skipping line 1017: expected 2 fields, saw 3
# Skipping line 1020: expected 2 fields, saw 3
# Skipping line 1021: expected 2 fields, saw 3
# Skipping line 1023: expected 2 fields, saw 4
# Skipping line 1031: expected 2 fields, saw 3
# Skipping line 1034: expected 2 fields, saw 3
# Skipping line 1035: expected 2 fields, saw 3
# Skipping line 1041: expected 2 fields, saw 3
# Skipping line 1042: expected 2 fields, saw 3
# Skipping line 1044: expected 2 fields, saw 3
# Skipping line 1046: expected 2 fields, saw 3
# Skipping line 1052: expected 2 fields, saw 3
# Skipping line 1055: expected 2 fields, saw 3
# Skipping line 1063: expected 2 fields, saw 3
# Skipping line 1071: expected 2 fields, saw 4
# Skipping line 1074: expected 2 fields, saw 4
# Skipping line 1078: expected 2 fields, saw 3
# Skipping line 1084: expected 2 fields, saw 3
# Skipping line 1098: expected 2 fields, saw 3
# Skipping line 1103: expected 2 fields, saw 3
# Skipping line 1105: expected 2 fields, saw 3
# Skipping line 1107: expected 2 fields, saw 3
# Skipping line 1108: expected 2 fields, saw 3
# Skipping line 1110: expected 2 fields, saw 3
# Skipping line 1111: expected 2 fields, saw 3
# Skipping line 1114: expected 2 fields, saw 3
# Skipping line 1116: expected 2 fields, saw 4
# Skipping line 1118: expected 2 fields, saw 4
# Skipping line 1119: expected 2 fields, saw 3
# Skipping line 1122: expected 2 fields, saw 3
# Skipping line 1124: expected 2 fields, saw 3
# Skipping line 1130: expected 2 fields, saw 4
# Skipping line 1134: expected 2 fields, saw 3
# Skipping line 1135: expected 2 fields, saw 3
# Skipping line 1136: expected 2 fields, saw 3
# Skipping line 1160: expected 2 fields, saw 3
# Skipping line 1166: expected 2 fields, saw 3
# Skipping line 1169: expected 2 fields, saw 3
# Skipping line 1185: expected 2 fields, saw 3
# Skipping line 1192: expected 2 fields, saw 3
# Skipping line 1199: expected 2 fields, saw 3
# Skipping line 1207: expected 2 fields, saw 5
# Skipping line 1209: expected 2 fields, saw 3
# Skipping line 1210: expected 2 fields, saw 3
# Skipping line 1226: expected 2 fields, saw 5
# Skipping line 1236: expected 2 fields, saw 3
# Skipping line 1248: expected 2 fields, saw 3
# Skipping line 1250: expected 2 fields, saw 3
# Skipping line 1255: expected 2 fields, saw 3
# Skipping line 1257: expected 2 fields, saw 4
# Skipping line 1259: expected 2 fields, saw 4
# Skipping line 1266: expected 2 fields, saw 3
# Skipping line 1268: expected 2 fields, saw 3
# Skipping line 1274: expected 2 fields, saw 3
# Skipping line 1282: expected 2 fields, saw 3
# Skipping line 1284: expected 2 fields, saw 3
# Skipping line 1299: expected 2 fields, saw 6
# Skipping line 1300: expected 2 fields, saw 3
# Skipping line 1313: expected 2 fields, saw 4
# Skipping line 1317: expected 2 fields, saw 3
# Skipping line 1319: expected 2 fields, saw 4
# Skipping line 1324: expected 2 fields, saw 3
# Skipping line 1325: expected 2 fields, saw 5
# Skipping line 1326: expected 2 fields, saw 4
# Skipping line 1328: expected 2 fields, saw 3
# Skipping line 1331: expected 2 fields, saw 3
# Skipping line 1336: expected 2 fields, saw 4
# Skipping line 1338: expected 2 fields, saw 4
# Skipping line 1339: expected 2 fields, saw 3
# Skipping line 1377: expected 2 fields, saw 3
# Skipping line 1398: expected 2 fields, saw 3
# Skipping line 1401: expected 2 fields, saw 3
# Skipping line 1402: expected 2 fields, saw 3
# Skipping line 1403: expected 2 fields, saw 3
# Skipping line 1406: expected 2 fields, saw 3
# Skipping line 1408: expected 2 fields, saw 3
# Skipping line 1410: expected 2 fields, saw 3
# Skipping line 1411: expected 2 fields, saw 3
# Skipping line 1412: expected 2 fields, saw 3
# Skipping line 1416: expected 2 fields, saw 3
# Skipping line 1420: expected 2 fields, saw 3
# Skipping line 1431: expected 2 fields, saw 3
# Skipping line 1436: expected 2 fields, saw 3
# Skipping line 1446: expected 2 fields, saw 3
# Skipping line 1451: expected 2 fields, saw 3
# Skipping line 1466: expected 2 fields, saw 3
# Skipping line 1469: expected 2 fields, saw 3
# Skipping line 1473: expected 2 fields, saw 3
# Skipping line 1478: expected 2 fields, saw 3
# Skipping line 1481: expected 2 fields, saw 4
# Skipping line 1486: expected 2 fields, saw 3
# Skipping line 1490: expected 2 fields, saw 6
# Skipping line 1506: expected 2 fields, saw 4
# Skipping line 1524: expected 2 fields, saw 3
# Skipping line 1532: expected 2 fields, saw 4
# Skipping line 1546: expected 2 fields, saw 4
# Skipping line 1548: expected 2 fields, saw 4
# Skipping line 1565: expected 2 fields, saw 3
# Skipping line 1566: expected 2 fields, saw 3
# Skipping line 1568: expected 2 fields, saw 3
# Skipping line 1579: expected 2 fields, saw 3
# Skipping line 1582: expected 2 fields, saw 3
# Skipping line 1585: expected 2 fields, saw 3
# Skipping line 1587: expected 2 fields, saw 3
# Skipping line 1593: expected 2 fields, saw 3
# Skipping line 1596: expected 2 fields, saw 3
# Skipping line 1623: expected 2 fields, saw 3
# Skipping line 1644: expected 2 fields, saw 3
# Skipping line 1656: expected 2 fields, saw 3
# Skipping line 1662: expected 2 fields, saw 7
# Skipping line 1671: expected 2 fields, saw 3
# Skipping line 1672: expected 2 fields, saw 3
# Skipping line 1673: expected 2 fields, saw 6
# Skipping line 1704: expected 2 fields, saw 3
# Skipping line 1737: expected 2 fields, saw 3
# Skipping line 1740: expected 2 fields, saw 4
# Skipping line 1741: expected 2 fields, saw 3
# Skipping line 1742: expected 2 fields, saw 3
# Skipping line 1743: expected 2 fields, saw 7
# Skipping line 1744: expected 2 fields, saw 3
# Skipping line 1748: expected 2 fields, saw 3
# Skipping line 1752: expected 2 fields, saw 3
# Skipping line 1762: expected 2 fields, saw 3
# Skipping line 1763: expected 2 fields, saw 3
# Skipping line 1765: expected 2 fields, saw 3
# Skipping line 1767: expected 2 fields, saw 4
# Skipping line 1773: expected 2 fields, saw 3
# Skipping line 1784: expected 2 fields, saw 3
# Skipping line 1786: expected 2 fields, saw 4
# Skipping line 1790: expected 2 fields, saw 3
# Skipping line 1807: expected 2 fields, saw 8
# Skipping line 1808: expected 2 fields, saw 3
# Skipping line 1809: expected 2 fields, saw 3
# Skipping line 1816: expected 2 fields, saw 6
# Skipping line 1817: expected 2 fields, saw 3
# Skipping line 1829: expected 2 fields, saw 3
# Skipping line 1841: expected 2 fields, saw 3
# Skipping line 1847: expected 2 fields, saw 3
# Skipping line 1851: expected 2 fields, saw 3
# Skipping line 1858: expected 2 fields, saw 3
# Skipping line 1866: expected 2 fields, saw 4
# Skipping line 1867: expected 2 fields, saw 3
# Skipping line 1868: expected 2 fields, saw 3
# Skipping line 1869: expected 2 fields, saw 3
# Skipping line 1870: expected 2 fields, saw 3
# Skipping line 1872: expected 2 fields, saw 4
# Skipping line 1883: expected 2 fields, saw 3
# Skipping line 1886: expected 2 fields, saw 3
# Skipping line 1904: expected 2 fields, saw 3
# Skipping line 1920: expected 2 fields, saw 3
# Skipping line 1929: expected 2 fields, saw 3
# Skipping line 1932: expected 2 fields, saw 3
# Skipping line 1934: expected 2 fields, saw 3
# Skipping line 1935: expected 2 fields, saw 3
# Skipping line 1951: expected 2 fields, saw 3
# Skipping line 1955: expected 2 fields, saw 3
# Skipping line 1957: expected 2 fields, saw 4
# Skipping line 1963: expected 2 fields, saw 4
# Skipping line 1968: expected 2 fields, saw 4
# Skipping line 1971: expected 2 fields, saw 3
# Skipping line 1990: expected 2 fields, saw 3
# Skipping line 1996: expected 2 fields, saw 3
# Skipping line 1997: expected 2 fields, saw 4
# Skipping line 2004: expected 2 fields, saw 3
# Skipping line 2018: expected 2 fields, saw 3
# Skipping line 2021: expected 2 fields, saw 5
# Skipping line 2025: expected 2 fields, saw 4
# Skipping line 2032: expected 2 fields, saw 4
# Skipping line 2039: expected 2 fields, saw 3
# Skipping line 2041: expected 2 fields, saw 3
# Skipping line 2045: expected 2 fields, saw 4
# Skipping line 2051: expected 2 fields, saw 3
# Skipping line 2056: expected 2 fields, saw 5
# Skipping line 2058: expected 2 fields, saw 3
# Skipping line 2060: expected 2 fields, saw 3
# Skipping line 2065: expected 2 fields, saw 3
# Skipping line 2075: expected 2 fields, saw 3
# Skipping line 2078: expected 2 fields, saw 4
# Skipping line 2088: expected 2 fields, saw 3
# Skipping line 2104: expected 2 fields, saw 3
# Skipping line 2111: expected 2 fields, saw 8
# Skipping line 2112: expected 2 fields, saw 5
# Skipping line 2113: expected 2 fields, saw 4
# Skipping line 2119: expected 2 fields, saw 3
# Skipping line 2127: expected 2 fields, saw 3
# Skipping line 2134: expected 2 fields, saw 5
# Skipping line 2135: expected 2 fields, saw 3
# Skipping line 2136: expected 2 fields, saw 3
# Skipping line 2140: expected 2 fields, saw 3
# Skipping line 2144: expected 2 fields, saw 3
# Skipping line 2147: expected 2 fields, saw 3
# Skipping line 2171: expected 2 fields, saw 3
# Skipping line 2172: expected 2 fields, saw 3
# Skipping line 2177: expected 2 fields, saw 3
# Skipping line 2179: expected 2 fields, saw 3
# Skipping line 2183: expected 2 fields, saw 3
# Skipping line 2191: expected 2 fields, saw 3
# Skipping line 2192: expected 2 fields, saw 3
# Skipping line 2194: expected 2 fields, saw 4
# Skipping line 2208: expected 2 fields, saw 3
# Skipping line 2220: expected 2 fields, saw 7
# Skipping line 2223: expected 2 fields, saw 4
# Skipping line 2230: expected 2 fields, saw 3
# Skipping line 2255: expected 2 fields, saw 3
# Skipping line 2262: expected 2 fields, saw 3
# Skipping line 2269: expected 2 fields, saw 3
# Skipping line 2278: expected 2 fields, saw 5
# Skipping line 2279: expected 2 fields, saw 4
# Skipping line 2285: expected 2 fields, saw 3
# Skipping line 2290: expected 2 fields, saw 3
# Skipping line 2316: expected 2 fields, saw 3
# Skipping line 2320: expected 2 fields, saw 3
# Skipping line 2321: expected 2 fields, saw 4
# Skipping line 2324: expected 2 fields, saw 3
# Skipping line 2333: expected 2 fields, saw 3
# Skipping line 2342: expected 2 fields, saw 3
# Skipping line 2344: expected 2 fields, saw 3
# Skipping line 2346: expected 2 fields, saw 5
# Skipping line 2348: expected 2 fields, saw 3
# Skipping line 2349: expected 2 fields, saw 3
# Skipping line 2354: expected 2 fields, saw 4
# Skipping line 2356: expected 2 fields, saw 3
# Skipping line 2359: expected 2 fields, saw 3
# Skipping line 2360: expected 2 fields, saw 5
# Skipping line 2363: expected 2 fields, saw 3
# Skipping line 2365: expected 2 fields, saw 3
# Skipping line 2367: expected 2 fields, saw 5
# Skipping line 2368: expected 2 fields, saw 3
# Skipping line 2381: expected 2 fields, saw 5
# Skipping line 2389: expected 2 fields, saw 4
# Skipping line 2392: expected 2 fields, saw 3
# Skipping line 2395: expected 2 fields, saw 3
# Skipping line 2398: expected 2 fields, saw 4
# Skipping line 2400: expected 2 fields, saw 3
# Skipping line 2403: expected 2 fields, saw 3
# Skipping line 2407: expected 2 fields, saw 3
# Skipping line 2409: expected 2 fields, saw 3
# Skipping line 2410: expected 2 fields, saw 3
# Skipping line 2411: expected 2 fields, saw 3
# Skipping line 2414: expected 2 fields, saw 3
# Skipping line 2420: expected 2 fields, saw 3
# Skipping line 2436: expected 2 fields, saw 3
# Skipping line 2438: expected 2 fields, saw 4
# Skipping line 2439: expected 2 fields, saw 3
# Skipping line 2443: expected 2 fields, saw 3
# Skipping line 2445: expected 2 fields, saw 3
# Skipping line 2446: expected 2 fields, saw 3
# Skipping line 2452: expected 2 fields, saw 5
# Skipping line 2453: expected 2 fields, saw 4
# Skipping line 2458: expected 2 fields, saw 3
# Skipping line 2459: expected 2 fields, saw 3
# Skipping line 2460: expected 2 fields, saw 3
# Skipping line 2466: expected 2 fields, saw 3
# Skipping line 2467: expected 2 fields, saw 3
# Skipping line 2472: expected 2 fields, saw 3
# Skipping line 2478: expected 2 fields, saw 3
# Skipping line 2479: expected 2 fields, saw 3
# Skipping line 2480: expected 2 fields, saw 3
# Skipping line 2484: expected 2 fields, saw 3
# Skipping line 2501: expected 2 fields, saw 3
# Skipping line 2505: expected 2 fields, saw 3
# Skipping line 2507: expected 2 fields, saw 3
# Skipping line 2510: expected 2 fields, saw 4
# Skipping line 2525: expected 2 fields, saw 4
# Skipping line 2528: expected 2 fields, saw 6
# Skipping line 2529: expected 2 fields, saw 3
# Skipping line 2532: expected 2 fields, saw 3
# Skipping line 2544: expected 2 fields, saw 4
# Skipping line 2546: expected 2 fields, saw 3
# Skipping line 2556: expected 2 fields, saw 3
# Skipping line 2558: expected 2 fields, saw 3
# Skipping line 2562: expected 2 fields, saw 3
# Skipping line 2563: expected 2 fields, saw 3
# Skipping line 2571: expected 2 fields, saw 3
# Skipping line 2595: expected 2 fields, saw 4
# Skipping line 2603: expected 2 fields, saw 3
# Skipping line 2618: expected 2 fields, saw 3
# Skipping line 2628: expected 2 fields, saw 3
# Skipping line 2638: expected 2 fields, saw 3
# Skipping line 2642: expected 2 fields, saw 3
# Skipping line 2649: expected 2 fields, saw 3
# Skipping line 2654: expected 2 fields, saw 3
# Skipping line 2665: expected 2 fields, saw 3
# Skipping line 2667: expected 2 fields, saw 3
# Skipping line 2668: expected 2 fields, saw 3
# Skipping line 2675: expected 2 fields, saw 5
# Skipping line 2677: expected 2 fields, saw 5
# Skipping line 2680: expected 2 fields, saw 4
# Skipping line 2681: expected 2 fields, saw 4
# Skipping line 2683: expected 2 fields, saw 4
# Skipping line 2684: expected 2 fields, saw 3
# Skipping line 2688: expected 2 fields, saw 5
# Skipping line 2689: expected 2 fields, saw 3
# Skipping line 2701: expected 2 fields, saw 3
# Skipping line 2705: expected 2 fields, saw 3
# Skipping line 2718: expected 2 fields, saw 3
# Skipping line 2722: expected 2 fields, saw 3
# Skipping line 2726: expected 2 fields, saw 4
# Skipping line 2736: expected 2 fields, saw 3
# Skipping line 2753: expected 2 fields, saw 3
# Skipping line 2760: expected 2 fields, saw 5
# Skipping line 2766: expected 2 fields, saw 5
# Skipping line 2770: expected 2 fields, saw 3
# Skipping line 2772: expected 2 fields, saw 3
# Skipping line 2776: expected 2 fields, saw 4
# Skipping line 2777: expected 2 fields, saw 3
# Skipping line 2780: expected 2 fields, saw 3
# Skipping line 2787: expected 2 fields, saw 3
# Skipping line 2789: expected 2 fields, saw 3
# Skipping line 2793: expected 2 fields, saw 3
# Skipping line 2794: expected 2 fields, saw 3
# Skipping line 2795: expected 2 fields, saw 3
# Skipping line 2797: expected 2 fields, saw 3
# Skipping line 2804: expected 2 fields, saw 4
# Skipping line 2809: expected 2 fields, saw 3
# Skipping line 2810: expected 2 fields, saw 3
# Skipping line 2812: expected 2 fields, saw 5
# Skipping line 2841: expected 2 fields, saw 21
# Skipping line 2869: expected 2 fields, saw 3
# Skipping line 2886: expected 2 fields, saw 3
# Skipping line 2897: expected 2 fields, saw 3
# Skipping line 2908: expected 2 fields, saw 3
# Skipping line 2925: expected 2 fields, saw 3
# Skipping line 2926: expected 2 fields, saw 3
# Skipping line 2927: expected 2 fields, saw 3
# Skipping line 2942: expected 2 fields, saw 3
# Skipping line 2943: expected 2 fields, saw 4
# Skipping line 2945: expected 2 fields, saw 5
# Skipping line 2949: expected 2 fields, saw 3
# Skipping line 2977: expected 2 fields, saw 3
# Skipping line 2993: expected 2 fields, saw 3
# Skipping line 3002: expected 2 fields, saw 5
# Skipping line 3009: expected 2 fields, saw 3
# Skipping line 3031: expected 2 fields, saw 3
# Skipping line 3038: expected 2 fields, saw 3
# Skipping line 3051: expected 2 fields, saw 4
# Skipping line 3065: expected 2 fields, saw 3
# Skipping line 3066: expected 2 fields, saw 3
# Skipping line 3067: expected 2 fields, saw 3
# Skipping line 3074: expected 2 fields, saw 4
# Skipping line 3077: expected 2 fields, saw 4
# Skipping line 3080: expected 2 fields, saw 3
# Skipping line 3104: expected 2 fields, saw 3
# Skipping line 3115: expected 2 fields, saw 3
# Skipping line 3117: expected 2 fields, saw 3
# Skipping line 3153: expected 2 fields, saw 3
# Skipping line 3174: expected 2 fields, saw 3
# Skipping line 3191: expected 2 fields, saw 3
# Skipping line 3193: expected 2 fields, saw 3
# Skipping line 3196: expected 2 fields, saw 4
# Skipping line 3203: expected 2 fields, saw 4
# Skipping line 3208: expected 2 fields, saw 3
# Skipping line 3209: expected 2 fields, saw 4
# Skipping line 3212: expected 2 fields, saw 3
# Skipping line 3213: expected 2 fields, saw 5
# Skipping line 3214: expected 2 fields, saw 3
# Skipping line 3221: expected 2 fields, saw 3
# Skipping line 3228: expected 2 fields, saw 3
# Skipping line 3231: expected 2 fields, saw 3
# Skipping line 3234: expected 2 fields, saw 3
# Skipping line 3237: expected 2 fields, saw 4
# Skipping line 3238: expected 2 fields, saw 3
# Skipping line 3239: expected 2 fields, saw 3
# Skipping line 3256: expected 2 fields, saw 3
# Skipping line 3278: expected 2 fields, saw 4
# Skipping line 3286: expected 2 fields, saw 3
# Skipping line 3288: expected 2 fields, saw 3
# Skipping line 3290: expected 2 fields, saw 3
# Skipping line 3297: expected 2 fields, saw 3
# Skipping line 3303: expected 2 fields, saw 3
# Skipping line 3314: expected 2 fields, saw 4
# Skipping line 3321: expected 2 fields, saw 3
# Skipping line 3335: expected 2 fields, saw 3
# Skipping line 3339: expected 2 fields, saw 3
# Skipping line 3348: expected 2 fields, saw 8
# Skipping line 3355: expected 2 fields, saw 3
# Skipping line 3357: expected 2 fields, saw 3
# Skipping line 3369: expected 2 fields, saw 3
# Skipping line 3382: expected 2 fields, saw 3
# Skipping line 3397: expected 2 fields, saw 4
# Skipping line 3399: expected 2 fields, saw 3
# Skipping line 3402: expected 2 fields, saw 3
# Skipping line 3404: expected 2 fields, saw 3
# Skipping line 3405: expected 2 fields, saw 3
# Skipping line 3431: expected 2 fields, saw 3
# Skipping line 3440: expected 2 fields, saw 5
# Skipping line 3441: expected 2 fields, saw 3
# Skipping line 3442: expected 2 fields, saw 5
# Skipping line 3447: expected 2 fields, saw 4
# Skipping line 3464: expected 2 fields, saw 3
# Skipping line 3470: expected 2 fields, saw 3
# Skipping line 3473: expected 2 fields, saw 3
# Skipping line 3482: expected 2 fields, saw 3
# Skipping line 3486: expected 2 fields, saw 3
# Skipping line 3487: expected 2 fields, saw 3
# Skipping line 3488: expected 2 fields, saw 3
# Skipping line 3489: expected 2 fields, saw 3
# Skipping line 3491: expected 2 fields, saw 4
# Skipping line 3494: expected 2 fields, saw 3
# Skipping line 3507: expected 2 fields, saw 4
# Skipping line 3519: expected 2 fields, saw 3
# Skipping line 3531: expected 2 fields, saw 3
# Skipping line 3551: expected 2 fields, saw 3
# Skipping line 3556: expected 2 fields, saw 3
# Skipping line 3557: expected 2 fields, saw 4
# Skipping line 3560: expected 2 fields, saw 3
# Skipping line 3562: expected 2 fields, saw 3
# Skipping line 3563: expected 2 fields, saw 3
# Skipping line 3567: expected 2 fields, saw 3
# Skipping line 3570: expected 2 fields, saw 3
# Skipping line 3575: expected 2 fields, saw 5
# Skipping line 3576: expected 2 fields, saw 3
# Skipping line 3577: expected 2 fields, saw 3
# Skipping line 3582: expected 2 fields, saw 4
# Skipping line 3590: expected 2 fields, saw 3
# Skipping line 3594: expected 2 fields, saw 3
# Skipping line 3596: expected 2 fields, saw 3
# Skipping line 3597: expected 2 fields, saw 3
# Skipping line 3602: expected 2 fields, saw 4
# Skipping line 3603: expected 2 fields, saw 6
# Skipping line 3604: expected 2 fields, saw 3
# Skipping line 3606: expected 2 fields, saw 6
# Skipping line 3608: expected 2 fields, saw 3
# Skipping line 3612: expected 2 fields, saw 3
# Skipping line 3655: expected 2 fields, saw 3
# Skipping line 3662: expected 2 fields, saw 3
# Skipping line 3663: expected 2 fields, saw 4
# Skipping line 3664: expected 2 fields, saw 3
# Skipping line 3665: expected 2 fields, saw 3
# Skipping line 3669: expected 2 fields, saw 9
# Skipping line 3678: expected 2 fields, saw 3
# Skipping line 3679: expected 2 fields, saw 4
# Skipping line 3689: expected 2 fields, saw 3
# Skipping line 3693: expected 2 fields, saw 3
# Skipping line 3694: expected 2 fields, saw 3
# Skipping line 3708: expected 2 fields, saw 3
# Skipping line 3713: expected 2 fields, saw 3
# Skipping line 3720: expected 2 fields, saw 5
# Skipping line 3721: expected 2 fields, saw 3
# Skipping line 3725: expected 2 fields, saw 3
# Skipping line 3728: expected 2 fields, saw 3
# Skipping line 3735: expected 2 fields, saw 5
# Skipping line 3749: expected 2 fields, saw 4
# Skipping line 3750: expected 2 fields, saw 3
# Skipping line 3754: expected 2 fields, saw 3
# Skipping line 3756: expected 2 fields, saw 3
# Skipping line 3770: expected 2 fields, saw 3
# Skipping line 3788: expected 2 fields, saw 3
# Skipping line 3795: expected 2 fields, saw 3
# Skipping line 3810: expected 2 fields, saw 3
# Skipping line 3826: expected 2 fields, saw 3
# Skipping line 3851: expected 2 fields, saw 3
# Skipping line 3853: expected 2 fields, saw 3
# Skipping line 3862: expected 2 fields, saw 3
# Skipping line 3864: expected 2 fields, saw 3
# Skipping line 3874: expected 2 fields, saw 3
# Skipping line 3886: expected 2 fields, saw 3
# Skipping line 3896: expected 2 fields, saw 3
# Skipping line 3897: expected 2 fields, saw 4
# Skipping line 3904: expected 2 fields, saw 3
# Skipping line 3908: expected 2 fields, saw 3
# Skipping line 3939: expected 2 fields, saw 3
# Skipping line 3945: expected 2 fields, saw 4
# Skipping line 3952: expected 2 fields, saw 4
# Skipping line 3959: expected 2 fields, saw 5
# Skipping line 3964: expected 2 fields, saw 4
# Skipping line 3972: expected 2 fields, saw 3
# Skipping line 3989: expected 2 fields, saw 3
# Skipping line 3990: expected 2 fields, saw 3
# Skipping line 3993: expected 2 fields, saw 3
# Skipping line 3996: expected 2 fields, saw 3
# Skipping line 4050: expected 2 fields, saw 4
# Skipping line 4063: expected 2 fields, saw 3
# Skipping line 4067: expected 2 fields, saw 3
# Skipping line 4074: expected 2 fields, saw 5
# Skipping line 4080: expected 2 fields, saw 3
# Skipping line 4095: expected 2 fields, saw 3
# Skipping line 4102: expected 2 fields, saw 4
# Skipping line 4163: expected 2 fields, saw 3
# Skipping line 4170: expected 2 fields, saw 3
# Skipping line 4189: expected 2 fields, saw 3
# Skipping line 4194: expected 2 fields, saw 3
# Skipping line 4206: expected 2 fields, saw 3
# Skipping line 4218: expected 2 fields, saw 3
# Skipping line 4236: expected 2 fields, saw 3
# Skipping line 4241: expected 2 fields, saw 3
# Skipping line 4252: expected 2 fields, saw 4
# Skipping line 4254: expected 2 fields, saw 3
# Skipping line 4260: expected 2 fields, saw 3
# Skipping line 4262: expected 2 fields, saw 3
# Skipping line 4264: expected 2 fields, saw 3
# Skipping line 4269: expected 2 fields, saw 3
# Skipping line 4278: expected 2 fields, saw 4
# Skipping line 4281: expected 2 fields, saw 3
# Skipping line 4284: expected 2 fields, saw 3
# Skipping line 4287: expected 2 fields, saw 3
# Skipping line 4292: expected 2 fields, saw 3
# Skipping line 4296: expected 2 fields, saw 4
# Skipping line 4298: expected 2 fields, saw 3
# Skipping line 4299: expected 2 fields, saw 4
# Skipping line 4303: expected 2 fields, saw 3
# Skipping line 4319: expected 2 fields, saw 3
# Skipping line 4358: expected 2 fields, saw 5
# Skipping line 4359: expected 2 fields, saw 4
# Skipping line 4368: expected 2 fields, saw 3
# Skipping line 4375: expected 2 fields, saw 3
# Skipping line 4396: expected 2 fields, saw 4
# Skipping line 4397: expected 2 fields, saw 3
# Skipping line 4400: expected 2 fields, saw 5
# Skipping line 4408: expected 2 fields, saw 3
# Skipping line 4414: expected 2 fields, saw 8
# Skipping line 4415: expected 2 fields, saw 3
# Skipping line 4417: expected 2 fields, saw 3
# Skipping line 4424: expected 2 fields, saw 3
# Skipping line 4427: expected 2 fields, saw 3
# Skipping line 4453: expected 2 fields, saw 3
# Skipping line 4454: expected 2 fields, saw 3
# Skipping line 4459: expected 2 fields, saw 3
# Skipping line 4465: expected 2 fields, saw 3
# Skipping line 4468: expected 2 fields, saw 3
# Skipping line 4472: expected 2 fields, saw 3
# Skipping line 4473: expected 2 fields, saw 4
# Skipping line 4474: expected 2 fields, saw 3
# Skipping line 4479: expected 2 fields, saw 6
# Skipping line 4480: expected 2 fields, saw 4
# Skipping line 4482: expected 2 fields, saw 3
# Skipping line 4486: expected 2 fields, saw 4
# Skipping line 4489: expected 2 fields, saw 3
# Skipping line 4491: expected 2 fields, saw 3
# Skipping line 4504: expected 2 fields, saw 4
# Skipping line 4505: expected 2 fields, saw 3
# Skipping line 4514: expected 2 fields, saw 3
# Skipping line 4517: expected 2 fields, saw 6
# Skipping line 4523: expected 2 fields, saw 3
# Skipping line 4528: expected 2 fields, saw 3
# Skipping line 4529: expected 2 fields, saw 4
# Skipping line 4532: expected 2 fields, saw 3
# Skipping line 4534: expected 2 fields, saw 4
# Skipping line 4549: expected 2 fields, saw 4
# Skipping line 4551: expected 2 fields, saw 3
# Skipping line 4552: expected 2 fields, saw 3
# Skipping line 4555: expected 2 fields, saw 3
# Skipping line 4557: expected 2 fields, saw 5
# Skipping line 4560: expected 2 fields, saw 3
# Skipping line 4564: expected 2 fields, saw 3
# Skipping line 4568: expected 2 fields, saw 3
# Skipping line 4587: expected 2 fields, saw 3
# Skipping line 4595: expected 2 fields, saw 3
# Skipping line 4604: expected 2 fields, saw 3
# Skipping line 4606: expected 2 fields, saw 4
# Skipping line 4625: expected 2 fields, saw 4
# Skipping line 4627: expected 2 fields, saw 4
# Skipping line 4633: expected 2 fields, saw 3
# Skipping line 4635: expected 2 fields, saw 6
# Skipping line 4644: expected 2 fields, saw 3
# Skipping line 4657: expected 2 fields, saw 3
# Skipping line 4666: expected 2 fields, saw 3
# Skipping line 4699: expected 2 fields, saw 3
# Skipping line 4715: expected 2 fields, saw 6
# Skipping line 4720: expected 2 fields, saw 3
# Skipping line 4723: expected 2 fields, saw 3
# Skipping line 4725: expected 2 fields, saw 5
# Skipping line 4727: expected 2 fields, saw 6
# Skipping line 4729: expected 2 fields, saw 5
# Skipping line 4731: expected 2 fields, saw 3
# Skipping line 4733: expected 2 fields, saw 3
# Skipping line 4734: expected 2 fields, saw 4
# Skipping line 4738: expected 2 fields, saw 3
# Skipping line 4743: expected 2 fields, saw 3
# Skipping line 4751: expected 2 fields, saw 3
# Skipping line 4758: expected 2 fields, saw 3
# Skipping line 4761: expected 2 fields, saw 3
# Skipping line 4766: expected 2 fields, saw 4
# Skipping line 4775: expected 2 fields, saw 3
# Skipping line 4783: expected 2 fields, saw 3
# Skipping line 4794: expected 2 fields, saw 3
# Skipping line 4798: expected 2 fields, saw 3
# Skipping line 4806: expected 2 fields, saw 3
# Skipping line 4808: expected 2 fields, saw 3
# Skipping line 4816: expected 2 fields, saw 3
# Skipping line 4818: expected 2 fields, saw 3
# Skipping line 4823: expected 2 fields, saw 4
# Skipping line 4827: expected 2 fields, saw 3
# Skipping line 4828: expected 2 fields, saw 3
# Skipping line 4830: expected 2 fields, saw 3
# Skipping line 4831: expected 2 fields, saw 3
# Skipping line 4832: expected 2 fields, saw 6
# Skipping line 4835: expected 2 fields, saw 3
# Skipping line 4836: expected 2 fields, saw 3
# Skipping line 4840: expected 2 fields, saw 3
# Skipping line 4841: expected 2 fields, saw 4
# Skipping line 4845: expected 2 fields, saw 3
# Skipping line 4848: expected 2 fields, saw 3
# Skipping line 4850: expected 2 fields, saw 3
# Skipping line 4852: expected 2 fields, saw 3
# Skipping line 4858: expected 2 fields, saw 3
# Skipping line 4859: expected 2 fields, saw 3
# Skipping line 4866: expected 2 fields, saw 3
# Skipping line 4871: expected 2 fields, saw 8
# Skipping line 4877: expected 2 fields, saw 4
# Skipping line 4881: expected 2 fields, saw 4
# Skipping line 4882: expected 2 fields, saw 4
# Skipping line 4890: expected 2 fields, saw 3
# Skipping line 4891: expected 2 fields, saw 3
# Skipping line 4892: expected 2 fields, saw 3
# Skipping line 4898: expected 2 fields, saw 3
# Skipping line 4900: expected 2 fields, saw 4
# Skipping line 4902: expected 2 fields, saw 3
# Skipping line 4908: expected 2 fields, saw 4
# Skipping line 4911: expected 2 fields, saw 3
# Skipping line 4914: expected 2 fields, saw 3
# Skipping line 4923: expected 2 fields, saw 4
# Skipping line 4929: expected 2 fields, saw 3
# Skipping line 4935: expected 2 fields, saw 3
# Skipping line 4936: expected 2 fields, saw 4
# Skipping line 4937: expected 2 fields, saw 3
# Skipping line 4938: expected 2 fields, saw 3
# Skipping line 4939: expected 2 fields, saw 3
# Skipping line 4941: expected 2 fields, saw 3
# Skipping line 4985: expected 2 fields, saw 6
# Skipping line 4988: expected 2 fields, saw 3
# Skipping line 4995: expected 2 fields, saw 3
# Skipping line 4996: expected 2 fields, saw 4
# Skipping line 4999: expected 2 fields, saw 3
# Skipping line 5026: expected 2 fields, saw 3
# Skipping line 5027: expected 2 fields, saw 10
# Skipping line 5028: expected 2 fields, saw 4
# Skipping line 5030: expected 2 fields, saw 3
# Skipping line 5032: expected 2 fields, saw 3
# Skipping line 5042: expected 2 fields, saw 3
# Skipping line 5045: expected 2 fields, saw 3
# Skipping line 5049: expected 2 fields, saw 5
# Skipping line 5053: expected 2 fields, saw 3
# Skipping line 5060: expected 2 fields, saw 4
# Skipping line 5067: expected 2 fields, saw 3
# Skipping line 5090: expected 2 fields, saw 3
# Skipping line 5092: expected 2 fields, saw 3
# Skipping line 5094: expected 2 fields, saw 3
# Skipping line 5101: expected 2 fields, saw 3
# Skipping line 5103: expected 2 fields, saw 3
# Skipping line 5116: expected 2 fields, saw 3
# Skipping line 5144: expected 2 fields, saw 3
# Skipping line 5145: expected 2 fields, saw 6
# Skipping line 5147: expected 2 fields, saw 6
# Skipping line 5152: expected 2 fields, saw 3
# Skipping line 5157: expected 2 fields, saw 3
# Skipping line 5161: expected 2 fields, saw 7
# Skipping line 5172: expected 2 fields, saw 6
# Skipping line 5174: expected 2 fields, saw 6
# Skipping line 5182: expected 2 fields, saw 6
# Skipping line 5187: expected 2 fields, saw 6
# Skipping line 5190: expected 2 fields, saw 4
# Skipping line 5198: expected 2 fields, saw 7
# Skipping line 5206: expected 2 fields, saw 7
# Skipping line 5218: expected 2 fields, saw 6
# Skipping line 5220: expected 2 fields, saw 3
# Skipping line 5224: expected 2 fields, saw 3
# Skipping line 5225: expected 2 fields, saw 3
# Skipping line 5228: expected 2 fields, saw 3
# Skipping line 5233: expected 2 fields, saw 3
# Skipping line 5269: expected 2 fields, saw 3
# Skipping line 5300: expected 2 fields, saw 3
# Skipping line 5317: expected 2 fields, saw 3
# Skipping line 5333: expected 2 fields, saw 3
# Skipping line 5339: expected 2 fields, saw 3
# Skipping line 5346: expected 2 fields, saw 3
# Skipping line 5372: expected 2 fields, saw 3
# Skipping line 5375: expected 2 fields, saw 5
# Skipping line 5386: expected 2 fields, saw 6
# Skipping line 5388: expected 2 fields, saw 5
# Skipping line 5391: expected 2 fields, saw 4
# Skipping line 5392: expected 2 fields, saw 3
# Skipping line 5393: expected 2 fields, saw 5
# Skipping line 5395: expected 2 fields, saw 3
# Skipping line 5397: expected 2 fields, saw 5
# Skipping line 5398: expected 2 fields, saw 3
# Skipping line 5403: expected 2 fields, saw 3
# Skipping line 5407: expected 2 fields, saw 3
# Skipping line 5409: expected 2 fields, saw 5
# Skipping line 5419: expected 2 fields, saw 3
# Skipping line 5420: expected 2 fields, saw 3
# Skipping line 5421: expected 2 fields, saw 3
# Skipping line 5434: expected 2 fields, saw 3
# Skipping line 5436: expected 2 fields, saw 3
# Skipping line 5440: expected 2 fields, saw 3
# Skipping line 5447: expected 2 fields, saw 7
# Skipping line 5448: expected 2 fields, saw 3
# Skipping line 5449: expected 2 fields, saw 3
# Skipping line 5452: expected 2 fields, saw 3
# Skipping line 5454: expected 2 fields, saw 3
# Skipping line 5469: expected 2 fields, saw 3
# Skipping line 5471: expected 2 fields, saw 7
# Skipping line 5491: expected 2 fields, saw 3
# Skipping line 5541: expected 2 fields, saw 4
# Skipping line 5559: expected 2 fields, saw 3
# Skipping line 5563: expected 2 fields, saw 3
# Skipping line 5570: expected 2 fields, saw 4
# Skipping line 5571: expected 2 fields, saw 5
# Skipping line 5573: expected 2 fields, saw 4
# Skipping line 5576: expected 2 fields, saw 5
# Skipping line 5596: expected 2 fields, saw 3
# Skipping line 5597: expected 2 fields, saw 3
# Skipping line 5601: expected 2 fields, saw 3
# Skipping line 5605: expected 2 fields, saw 3
# Skipping line 5607: expected 2 fields, saw 3
# Skipping line 5609: expected 2 fields, saw 3
# Skipping line 5610: expected 2 fields, saw 5
# Skipping line 5612: expected 2 fields, saw 4
# Skipping line 5623: expected 2 fields, saw 4
# Skipping line 5626: expected 2 fields, saw 3
# Skipping line 5637: expected 2 fields, saw 3
# Skipping line 5640: expected 2 fields, saw 3
# Skipping line 5643: expected 2 fields, saw 4
# Skipping line 5645: expected 2 fields, saw 4
# Skipping line 5646: expected 2 fields, saw 3
# Skipping line 5647: expected 2 fields, saw 4
# Skipping line 5648: expected 2 fields, saw 4
# Skipping line 5670: expected 2 fields, saw 4
# Skipping line 5677: expected 2 fields, saw 3
# Skipping line 5684: expected 2 fields, saw 4
# Skipping line 5698: expected 2 fields, saw 3
# Skipping line 5705: expected 2 fields, saw 4
# Skipping line 5707: expected 2 fields, saw 3
# Skipping line 5709: expected 2 fields, saw 3
# Skipping line 5711: expected 2 fields, saw 3
# Skipping line 5712: expected 2 fields, saw 3
# Skipping line 5722: expected 2 fields, saw 5
# Skipping line 5728: expected 2 fields, saw 3
# Skipping line 5758: expected 2 fields, saw 6
# Skipping line 5759: expected 2 fields, saw 6
# Skipping line 5767: expected 2 fields, saw 3
# Skipping line 5778: expected 2 fields, saw 3
# Skipping line 5780: expected 2 fields, saw 4
# Skipping line 5787: expected 2 fields, saw 6
# Skipping line 5792: expected 2 fields, saw 12
# Skipping line 5817: expected 2 fields, saw 3
# Skipping line 5843: expected 2 fields, saw 3
# Skipping line 5847: expected 2 fields, saw 4
# Skipping line 5849: expected 2 fields, saw 4
# Skipping line 5851: expected 2 fields, saw 3
# Skipping line 5854: expected 2 fields, saw 3
# Skipping line 5869: expected 2 fields, saw 4
# Skipping line 5873: expected 2 fields, saw 3
# Skipping line 5902: expected 2 fields, saw 3
# Skipping line 5906: expected 2 fields, saw 4
# Skipping line 5907: expected 2 fields, saw 7
# Skipping line 5908: expected 2 fields, saw 5
# Skipping line 5909: expected 2 fields, saw 6
# Skipping line 5912: expected 2 fields, saw 3
# Skipping line 5914: expected 2 fields, saw 3
# Skipping line 5915: expected 2 fields, saw 3
# Skipping line 5917: expected 2 fields, saw 3
# Skipping line 5919: expected 2 fields, saw 4
# Skipping line 5920: expected 2 fields, saw 4
# Skipping line 5921: expected 2 fields, saw 3
# Skipping line 5922: expected 2 fields, saw 4
# Skipping line 5923: expected 2 fields, saw 4
# Skipping line 5929: expected 2 fields, saw 3
# Skipping line 5934: expected 2 fields, saw 3
# Skipping line 5935: expected 2 fields, saw 3
# Skipping line 5937: expected 2 fields, saw 5
# Skipping line 5938: expected 2 fields, saw 3
# Skipping line 5948: expected 2 fields, saw 3
# Skipping line 5949: expected 2 fields, saw 6
# Skipping line 5952: expected 2 fields, saw 3
# Skipping line 5957: expected 2 fields, saw 8
# Skipping line 5960: expected 2 fields, saw 5
# Skipping line 5968: expected 2 fields, saw 5
# Skipping line 5971: expected 2 fields, saw 3
# Skipping line 6025: expected 2 fields, saw 4
# Skipping line 6032: expected 2 fields, saw 3
# Skipping line 6036: expected 2 fields, saw 10
# Skipping line 6039: expected 2 fields, saw 3
# Skipping line 6041: expected 2 fields, saw 3
# Skipping line 6042: expected 2 fields, saw 3
# Skipping line 6044: expected 2 fields, saw 3
# Skipping line 6045: expected 2 fields, saw 3
# Skipping line 6046: expected 2 fields, saw 3
# Skipping line 6047: expected 2 fields, saw 3
# Skipping line 6048: expected 2 fields, saw 3
# Skipping line 6051: expected 2 fields, saw 3
# Skipping line 6052: expected 2 fields, saw 3
# Skipping line 6053: expected 2 fields, saw 7
# Skipping line 6054: expected 2 fields, saw 3
# Skipping line 6055: expected 2 fields, saw 3
# Skipping line 6060: expected 2 fields, saw 4
# Skipping line 6069: expected 2 fields, saw 3
# Skipping line 6083: expected 2 fields, saw 3
# Skipping line 6088: expected 2 fields, saw 3
# Skipping line 6089: expected 2 fields, saw 4
# Skipping line 6090: expected 2 fields, saw 4
# Skipping line 6097: expected 2 fields, saw 3
# Skipping line 6098: expected 2 fields, saw 3
# Skipping line 6099: expected 2 fields, saw 3
# Skipping line 6101: expected 2 fields, saw 6
# Skipping line 6102: expected 2 fields, saw 3
# Skipping line 6113: expected 2 fields, saw 3
# Skipping line 6115: expected 2 fields, saw 3
# Skipping line 6116: expected 2 fields, saw 3
# Skipping line 6130: expected 2 fields, saw 3
# Skipping line 6142: expected 2 fields, saw 3
# Skipping line 6159: expected 2 fields, saw 3
# Skipping line 6163: expected 2 fields, saw 3
# Skipping line 6172: expected 2 fields, saw 3
# Skipping line 6174: expected 2 fields, saw 3
# Skipping line 6175: expected 2 fields, saw 3
# Skipping line 6178: expected 2 fields, saw 3
# Skipping line 6189: expected 2 fields, saw 3
# Skipping line 6194: expected 2 fields, saw 3
# Skipping line 6196: expected 2 fields, saw 3
# Skipping line 6200: expected 2 fields, saw 5
# Skipping line 6210: expected 2 fields, saw 4
# Skipping line 6214: expected 2 fields, saw 3
# Skipping line 6218: expected 2 fields, saw 4
# Skipping line 6221: expected 2 fields, saw 4
# Skipping line 6226: expected 2 fields, saw 4
# Skipping line 6230: expected 2 fields, saw 3
# Skipping line 6234: expected 2 fields, saw 3
# Skipping line 6235: expected 2 fields, saw 3
# Skipping line 6253: expected 2 fields, saw 3
# Skipping line 6254: expected 2 fields, saw 3
# Skipping line 6255: expected 2 fields, saw 3
# Skipping line 6265: expected 2 fields, saw 3
# Skipping line 6269: expected 2 fields, saw 3
# Skipping line 6273: expected 2 fields, saw 5
# Skipping line 6274: expected 2 fields, saw 3
# Skipping line 6280: expected 2 fields, saw 3
# Skipping line 6282: expected 2 fields, saw 4
# Skipping line 6284: expected 2 fields, saw 3
# Skipping line 6285: expected 2 fields, saw 3
# Skipping line 6286: expected 2 fields, saw 9
# Skipping line 6295: expected 2 fields, saw 3
# Skipping line 6297: expected 2 fields, saw 3
# Skipping line 6311: expected 2 fields, saw 3
# Skipping line 6317: expected 2 fields, saw 3
# Skipping line 6325: expected 2 fields, saw 3
# Skipping line 6345: expected 2 fields, saw 6
# Skipping line 6348: expected 2 fields, saw 3
# Skipping line 6349: expected 2 fields, saw 3
# Skipping line 6350: expected 2 fields, saw 3
# Skipping line 6355: expected 2 fields, saw 5
# Skipping line 6366: expected 2 fields, saw 3
# Skipping line 6378: expected 2 fields, saw 3
# Skipping line 6383: expected 2 fields, saw 3
# Skipping line 6391: expected 2 fields, saw 3
# Skipping line 6393: expected 2 fields, saw 3
# Skipping line 6397: expected 2 fields, saw 4
# Skipping line 6400: expected 2 fields, saw 3
# Skipping line 6404: expected 2 fields, saw 3
# Skipping line 6411: expected 2 fields, saw 3
# Skipping line 6414: expected 2 fields, saw 3
# Skipping line 6415: expected 2 fields, saw 3
# Skipping line 6419: expected 2 fields, saw 3
# Skipping line 6467: expected 2 fields, saw 3
# Skipping line 6469: expected 2 fields, saw 3
# Skipping line 6472: expected 2 fields, saw 3
# Skipping line 6482: expected 2 fields, saw 4
# Skipping line 6483: expected 2 fields, saw 3
# Skipping line 6510: expected 2 fields, saw 3
# Skipping line 6511: expected 2 fields, saw 3
# Skipping line 6513: expected 2 fields, saw 3
# Skipping line 6529: expected 2 fields, saw 4
# Skipping line 6538: expected 2 fields, saw 3
# Skipping line 6539: expected 2 fields, saw 3
# Skipping line 6559: expected 2 fields, saw 3
# Skipping line 6586: expected 2 fields, saw 4
# Skipping line 6587: expected 2 fields, saw 3
# Skipping line 6588: expected 2 fields, saw 3
# Skipping line 6591: expected 2 fields, saw 4
# Skipping line 6595: expected 2 fields, saw 3
# Skipping line 6603: expected 2 fields, saw 4
# Skipping line 6609: expected 2 fields, saw 5
# Skipping line 6616: expected 2 fields, saw 3
# Skipping line 6627: expected 2 fields, saw 3
# Skipping line 6632: expected 2 fields, saw 3
# Skipping line 6634: expected 2 fields, saw 4
# Skipping line 6635: expected 2 fields, saw 3
# Skipping line 6661: expected 2 fields, saw 5
# Skipping line 6674: expected 2 fields, saw 4
# Skipping line 6682: expected 2 fields, saw 3
# Skipping line 6684: expected 2 fields, saw 3
# Skipping line 6691: expected 2 fields, saw 6
# Skipping line 6692: expected 2 fields, saw 3
# Skipping line 6698: expected 2 fields, saw 3
# Skipping line 6718: expected 2 fields, saw 5
# Skipping line 6733: expected 2 fields, saw 3
# Skipping line 6749: expected 2 fields, saw 3
# Skipping line 6756: expected 2 fields, saw 7
# Skipping line 6759: expected 2 fields, saw 5
# Skipping line 6761: expected 2 fields, saw 3
# Skipping line 6765: expected 2 fields, saw 3
# Skipping line 6766: expected 2 fields, saw 4
# Skipping line 6771: expected 2 fields, saw 4
# Skipping line 6775: expected 2 fields, saw 3
# Skipping line 6779: expected 2 fields, saw 3
# ...
# Skipping line 14877: expected 2 fields, saw 3
# Skipping line 14878: expected 2 fields, saw 3
# Skipping line 14880: expected 2 fields, saw 4
# Skipping line 14891: expected 2 fields, saw 3
# Skipping line 14893: expected 2 fields, saw 3
# Skipping line 14894: expected 2 fields, saw 4
# Skipping line 14897: expected 2 fields, saw 4
# Skipping line 14898: expected 2 fields, saw 3
# Skipping line 14903: expected 2 fields, saw 3
# Skipping line 14904: expected 2 fields, saw 3
# Skipping line 14905: expected 2 fields, saw 3
# Skipping line 14907: expected 2 fields, saw 3
# Skipping line 14908: expected 2 fields, saw 7
# Skipping line 14910: expected 2 fields, saw 3
# Skipping line 14922: expected 2 fields, saw 3
# Skipping line 14924: expected 2 fields, saw 4
# Skipping line 14932: expected 2 fields, saw 3
# Skipping line 14933: expected 2 fields, saw 3
# Skipping line 14935: expected 2 fields, saw 3
# Skipping line 14936: expected 2 fields, saw 5
# Skipping line 14937: expected 2 fields, saw 4
# Skipping line 14938: expected 2 fields, saw 3
# Skipping line 14940: expected 2 fields, saw 3
# Skipping line 14943: expected 2 fields, saw 3
# Skipping line 14944: expected 2 fields, saw 4
# Skipping line 14945: expected 2 fields, saw 3
# Skipping line 14949: expected 2 fields, saw 4
# Skipping line 14953: expected 2 fields, saw 3
# Skipping line 14964: expected 2 fields, saw 3
# Skipping line 14965: expected 2 fields, saw 3
# Skipping line 14969: expected 2 fields, saw 3
# Skipping line 14985: expected 2 fields, saw 4
# Skipping line 14986: expected 2 fields, saw 6
# Skipping line 14987: expected 2 fields, saw 3
# Skipping line 14988: expected 2 fields, saw 4
# Skipping line 15013: expected 2 fields, saw 3
# Skipping line 15014: expected 2 fields, saw 4
# Skipping line 15016: expected 2 fields, saw 3
# Skipping line 15018: expected 2 fields, saw 5
# Skipping line 15024: expected 2 fields, saw 3
# Skipping line 15026: expected 2 fields, saw 3
# Skipping line 15037: expected 2 fields, saw 9
# Skipping line 15038: expected 2 fields, saw 3
# Skipping line 15039: expected 2 fields, saw 3
# Skipping line 15040: expected 2 fields, saw 5
# Skipping line 15049: expected 2 fields, saw 5
# Skipping line 15052: expected 2 fields, saw 3
# Skipping line 15053: expected 2 fields, saw 3
# Skipping line 15054: expected 2 fields, saw 3
# Skipping line 15060: expected 2 fields, saw 3
# Skipping line 15061: expected 2 fields, saw 3
# Skipping line 15062: expected 2 fields, saw 3
# Skipping line 15063: expected 2 fields, saw 3
# Skipping line 15064: expected 2 fields, saw 3
# Skipping line 15068: expected 2 fields, saw 3
# Skipping line 15070: expected 2 fields, saw 3
# Skipping line 15085: expected 2 fields, saw 3
# Skipping line 15098: expected 2 fields, saw 4
# Skipping line 15100: expected 2 fields, saw 6
# Skipping line 15104: expected 2 fields, saw 5
# Skipping line 15105: expected 2 fields, saw 5
# Skipping line 15107: expected 2 fields, saw 4
# Skipping line 15118: expected 2 fields, saw 5
# Skipping line 15120: expected 2 fields, saw 3
# Skipping line 15123: expected 2 fields, saw 5
# Skipping line 15133: expected 2 fields, saw 3
# Skipping line 15135: expected 2 fields, saw 3
# Skipping line 15138: expected 2 fields, saw 3
# Skipping line 15139: expected 2 fields, saw 4
# Skipping line 15148: expected 2 fields, saw 5
# Skipping line 15157: expected 2 fields, saw 3
# Skipping line 15161: expected 2 fields, saw 5
# Skipping line 15162: expected 2 fields, saw 3
# Skipping line 15175: expected 2 fields, saw 6
# Skipping line 15176: expected 2 fields, saw 3
# Skipping line 15177: expected 2 fields, saw 4
# Skipping line 15179: expected 2 fields, saw 5
# Skipping line 15181: expected 2 fields, saw 3
# Skipping line 15182: expected 2 fields, saw 5
# Skipping line 15184: expected 2 fields, saw 3
# Skipping line 15187: expected 2 fields, saw 6
# Skipping line 15191: expected 2 fields, saw 3
# Skipping line 15199: expected 2 fields, saw 3
# Skipping line 15201: expected 2 fields, saw 3
# Skipping line 15209: expected 2 fields, saw 3
# Skipping line 15210: expected 2 fields, saw 3
# Skipping line 15214: expected 2 fields, saw 3
# Skipping line 15217: expected 2 fields, saw 4
# Skipping line 15218: expected 2 fields, saw 3
# Skipping line 15219: expected 2 fields, saw 3
# Skipping line 15221: expected 2 fields, saw 4
# Skipping line 15228: expected 2 fields, saw 3
# Skipping line 15229: expected 2 fields, saw 6
# Skipping line 15230: expected 2 fields, saw 4
# Skipping line 15232: expected 2 fields, saw 3
# Skipping line 15233: expected 2 fields, saw 5
# Skipping line 15234: expected 2 fields, saw 4
# Skipping line 15237: expected 2 fields, saw 4
# Skipping line 15238: expected 2 fields, saw 8
# Skipping line 15246: expected 2 fields, saw 3
# Skipping line 15256: expected 2 fields, saw 3
# Skipping line 15262: expected 2 fields, saw 5
# Skipping line 15263: expected 2 fields, saw 3
# Skipping line 15265: expected 2 fields, saw 6
# Skipping line 15269: expected 2 fields, saw 3
# Skipping line 15271: expected 2 fields, saw 3
# Skipping line 15275: expected 2 fields, saw 3
# Skipping line 15279: expected 2 fields, saw 6
# Skipping line 15282: expected 2 fields, saw 6
# Skipping line 15287: expected 2 fields, saw 8
# Skipping line 15290: expected 2 fields, saw 3
# Skipping line 15295: expected 2 fields, saw 5
# Skipping line 15300: expected 2 fields, saw 4
# Skipping line 15301: expected 2 fields, saw 4
# Skipping line 15326: expected 2 fields, saw 3
# Skipping line 15327: expected 2 fields, saw 3
# Skipping line 15345: expected 2 fields, saw 3
# Skipping line 15346: expected 2 fields, saw 3
# Skipping line 15347: expected 2 fields, saw 3
# Skipping line 15351: expected 2 fields, saw 3
# Skipping line 15355: expected 2 fields, saw 5
# Skipping line 15357: expected 2 fields, saw 5
# Skipping line 15360: expected 2 fields, saw 3
# Skipping line 15363: expected 2 fields, saw 4
# Skipping line 15366: expected 2 fields, saw 3
# Skipping line 15367: expected 2 fields, saw 3
# Skipping line 15373: expected 2 fields, saw 4
# Skipping line 15377: expected 2 fields, saw 3
# Skipping line 15382: expected 2 fields, saw 3
# Skipping line 15384: expected 2 fields, saw 3
# Skipping line 15401: expected 2 fields, saw 4
# Skipping line 15403: expected 2 fields, saw 4
# Skipping line 15412: expected 2 fields, saw 5
# Skipping line 15415: expected 2 fields, saw 3
# Skipping line 15416: expected 2 fields, saw 4
# Skipping line 15419: expected 2 fields, saw 3
# Skipping line 15424: expected 2 fields, saw 4
# Skipping line 15458: expected 2 fields, saw 3
# Skipping line 15461: expected 2 fields, saw 4
# Skipping line 15462: expected 2 fields, saw 3
# Skipping line 15464: expected 2 fields, saw 4
# Skipping line 15473: expected 2 fields, saw 3
# Skipping line 15479: expected 2 fields, saw 3
# Skipping line 15480: expected 2 fields, saw 3
# Skipping line 15481: expected 2 fields, saw 4
# Skipping line 15487: expected 2 fields, saw 3
# Skipping line 15488: expected 2 fields, saw 7
# Skipping line 15506: expected 2 fields, saw 3
# Skipping line 15508: expected 2 fields, saw 4
# Skipping line 15514: expected 2 fields, saw 5
# Skipping line 15515: expected 2 fields, saw 3
# Skipping line 15520: expected 2 fields, saw 4
# Skipping line 15521: expected 2 fields, saw 4
# Skipping line 15523: expected 2 fields, saw 3
# Skipping line 15524: expected 2 fields, saw 3
# Skipping line 15536: expected 2 fields, saw 4
# Skipping line 15537: expected 2 fields, saw 5
# Skipping line 15540: expected 2 fields, saw 4
# Skipping line 15542: expected 2 fields, saw 3
# Skipping line 15546: expected 2 fields, saw 4
# Skipping line 15551: expected 2 fields, saw 3
# Skipping line 15558: expected 2 fields, saw 4
# Skipping line 15559: expected 2 fields, saw 4
# Skipping line 15582: expected 2 fields, saw 3
# Skipping line 15587: expected 2 fields, saw 3
# Skipping line 15589: expected 2 fields, saw 3
# Skipping line 15609: expected 2 fields, saw 4
# Skipping line 15612: expected 2 fields, saw 4
# Skipping line 15616: expected 2 fields, saw 3
# Skipping line 15619: expected 2 fields, saw 3
# Skipping line 15620: expected 2 fields, saw 3
# Skipping line 15623: expected 2 fields, saw 6
# Skipping line 15627: expected 2 fields, saw 3
# Skipping line 15632: expected 2 fields, saw 3
# Skipping line 15656: expected 2 fields, saw 3
# Skipping line 15681: expected 2 fields, saw 5
# Skipping line 15682: expected 2 fields, saw 3
# Skipping line 15684: expected 2 fields, saw 3
# Skipping line 15685: expected 2 fields, saw 5
# Skipping line 15687: expected 2 fields, saw 3
# Skipping line 15694: expected 2 fields, saw 4
# Skipping line 15696: expected 2 fields, saw 4
# Skipping line 15697: expected 2 fields, saw 3
# Skipping line 15698: expected 2 fields, saw 4
# Skipping line 15704: expected 2 fields, saw 4
# Skipping line 15707: expected 2 fields, saw 3
# Skipping line 15710: expected 2 fields, saw 4
# Skipping line 15744: expected 2 fields, saw 3
# Skipping line 15753: expected 2 fields, saw 4
# Skipping line 15754: expected 2 fields, saw 3
# Skipping line 15755: expected 2 fields, saw 3
# Skipping line 15760: expected 2 fields, saw 3
# Skipping line 15765: expected 2 fields, saw 3
# Skipping line 15770: expected 2 fields, saw 3
# Skipping line 15773: expected 2 fields, saw 3
# Skipping line 15775: expected 2 fields, saw 3
# Skipping line 15776: expected 2 fields, saw 3
# Skipping line 15788: expected 2 fields, saw 5
# Skipping line 15799: expected 2 fields, saw 3
# Skipping line 15802: expected 2 fields, saw 4
# Skipping line 15803: expected 2 fields, saw 5
# Skipping line 15804: expected 2 fields, saw 4
# Skipping line 15805: expected 2 fields, saw 3
# Skipping line 15806: expected 2 fields, saw 5
# Skipping line 15808: expected 2 fields, saw 3
# Skipping line 15811: expected 2 fields, saw 4
# Skipping line 15822: expected 2 fields, saw 5
# Skipping line 15827: expected 2 fields, saw 4
# Skipping line 15828: expected 2 fields, saw 3
# Skipping line 15829: expected 2 fields, saw 4
# Skipping line 15833: expected 2 fields, saw 3
# Skipping line 15834: expected 2 fields, saw 3
# Skipping line 15838: expected 2 fields, saw 3
# Skipping line 15843: expected 2 fields, saw 4
# Skipping line 15860: expected 2 fields, saw 4
# Skipping line 15861: expected 2 fields, saw 3
# Skipping line 15862: expected 2 fields, saw 3
# Skipping line 15868: expected 2 fields, saw 4
# Skipping line 15871: expected 2 fields, saw 3
# Skipping line 15880: expected 2 fields, saw 3
# Skipping line 15882: expected 2 fields, saw 4
# Skipping line 15884: expected 2 fields, saw 4
# Skipping line 15885: expected 2 fields, saw 4
# Skipping line 15891: expected 2 fields, saw 3
# Skipping line 15892: expected 2 fields, saw 3
# Skipping line 15893: expected 2 fields, saw 5
# Skipping line 15896: expected 2 fields, saw 4
# Skipping line 15902: expected 2 fields, saw 5
# Skipping line 15915: expected 2 fields, saw 3
# Skipping line 15923: expected 2 fields, saw 3
# Skipping line 15932: expected 2 fields, saw 3
# Skipping line 15938: expected 2 fields, saw 4
# Skipping line 15953: expected 2 fields, saw 3
# Skipping line 15955: expected 2 fields, saw 3
# Skipping line 15963: expected 2 fields, saw 3
# Skipping line 15965: expected 2 fields, saw 3
# Skipping line 15966: expected 2 fields, saw 3
# Skipping line 15969: expected 2 fields, saw 3
# Skipping line 15981: expected 2 fields, saw 3
# Skipping line 15983: expected 2 fields, saw 5
# Skipping line 15984: expected 2 fields, saw 3
# Skipping line 15988: expected 2 fields, saw 6
# Skipping line 15990: expected 2 fields, saw 4
# Skipping line 15992: expected 2 fields, saw 3
# Skipping line 15995: expected 2 fields, saw 3
# Skipping line 16010: expected 2 fields, saw 3
# Skipping line 16014: expected 2 fields, saw 3
# Skipping line 16030: expected 2 fields, saw 3
# Skipping line 16037: expected 2 fields, saw 3
# Skipping line 16050: expected 2 fields, saw 3
# Skipping line 16054: expected 2 fields, saw 3
# Skipping line 16064: expected 2 fields, saw 3
# Skipping line 16065: expected 2 fields, saw 3
# Skipping line 16067: expected 2 fields, saw 3
# Skipping line 16075: expected 2 fields, saw 3
# Skipping line 16077: expected 2 fields, saw 3
# Skipping line 16080: expected 2 fields, saw 5
# Skipping line 16090: expected 2 fields, saw 4
# Skipping line 16091: expected 2 fields, saw 3
# Skipping line 16094: expected 2 fields, saw 6
# Skipping line 16096: expected 2 fields, saw 5
# Skipping line 16097: expected 2 fields, saw 3
# Skipping line 16100: expected 2 fields, saw 7
# Skipping line 16106: expected 2 fields, saw 3
# Skipping line 16110: expected 2 fields, saw 3
# Skipping line 16111: expected 2 fields, saw 3
# Skipping line 16113: expected 2 fields, saw 8
# Skipping line 16124: expected 2 fields, saw 6
# Skipping line 16127: expected 2 fields, saw 3
# Skipping line 16144: expected 2 fields, saw 3
# Skipping line 16146: expected 2 fields, saw 3
# Skipping line 16159: expected 2 fields, saw 3
# Skipping line 16175: expected 2 fields, saw 3
# Skipping line 16176: expected 2 fields, saw 3
# Skipping line 16177: expected 2 fields, saw 3
# Skipping line 16178: expected 2 fields, saw 3
# Skipping line 16181: expected 2 fields, saw 3
# Skipping line 16186: expected 2 fields, saw 3
# Skipping line 16191: expected 2 fields, saw 3
# Skipping line 16194: expected 2 fields, saw 3
# Skipping line 16208: expected 2 fields, saw 3
# Skipping line 16210: expected 2 fields, saw 3
# Skipping line 16226: expected 2 fields, saw 3
# Skipping line 16256: expected 2 fields, saw 3
# Skipping line 16263: expected 2 fields, saw 5
# Skipping line 16274: expected 2 fields, saw 5
# Skipping line 16275: expected 2 fields, saw 3
# Skipping line 16289: expected 2 fields, saw 4
# Skipping line 16296: expected 2 fields, saw 3
# Skipping line 16297: expected 2 fields, saw 5
# Skipping line 16301: expected 2 fields, saw 3
# Skipping line 16302: expected 2 fields, saw 3
# Skipping line 16304: expected 2 fields, saw 3
# Skipping line 16306: expected 2 fields, saw 3
# Skipping line 16314: expected 2 fields, saw 4
# Skipping line 16316: expected 2 fields, saw 3
# Skipping line 16333: expected 2 fields, saw 4
# Skipping line 16335: expected 2 fields, saw 4
# Skipping line 16337: expected 2 fields, saw 4
# Skipping line 16338: expected 2 fields, saw 4
# Skipping line 16341: expected 2 fields, saw 3
# Skipping line 16343: expected 2 fields, saw 3
# Skipping line 16345: expected 2 fields, saw 6
# Skipping line 16349: expected 2 fields, saw 3
# Skipping line 16353: expected 2 fields, saw 3
# Skipping line 16357: expected 2 fields, saw 3
# Skipping line 16360: expected 2 fields, saw 3
# Skipping line 16363: expected 2 fields, saw 3
# Skipping line 16369: expected 2 fields, saw 4
# Skipping line 16378: expected 2 fields, saw 3
# Skipping line 16392: expected 2 fields, saw 6
# Skipping line 16398: expected 2 fields, saw 5
# Skipping line 16401: expected 2 fields, saw 3
# Skipping line 16403: expected 2 fields, saw 5
# Skipping line 16406: expected 2 fields, saw 3
# Skipping line 16411: expected 2 fields, saw 3
# Skipping line 16413: expected 2 fields, saw 3
# Skipping line 16414: expected 2 fields, saw 4
# Skipping line 16437: expected 2 fields, saw 3
# Skipping line 16456: expected 2 fields, saw 3
# Skipping line 16474: expected 2 fields, saw 3
# Skipping line 16482: expected 2 fields, saw 3
# Skipping line 16487: expected 2 fields, saw 3
# Skipping line 16490: expected 2 fields, saw 3
# Skipping line 16497: expected 2 fields, saw 5
# Skipping line 16499: expected 2 fields, saw 3
# Skipping line 16500: expected 2 fields, saw 3
# Skipping line 16518: expected 2 fields, saw 3
# Skipping line 16525: expected 2 fields, saw 3
# Skipping line 16541: expected 2 fields, saw 3
# Skipping line 16543: expected 2 fields, saw 3
# Skipping line 16548: expected 2 fields, saw 3
# Skipping line 16552: expected 2 fields, saw 3
# Skipping line 16554: expected 2 fields, saw 4
# Skipping line 16587: expected 2 fields, saw 3
# Skipping line 16596: expected 2 fields, saw 4
# Skipping line 16598: expected 2 fields, saw 3
# Skipping line 16601: expected 2 fields, saw 3
# Skipping line 16606: expected 2 fields, saw 3
# Skipping line 16615: expected 2 fields, saw 5
# Skipping line 16616: expected 2 fields, saw 3
# Skipping line 16627: expected 2 fields, saw 3
# Skipping line 16629: expected 2 fields, saw 3
# Skipping line 16630: expected 2 fields, saw 3
# Skipping line 16636: expected 2 fields, saw 3
# Skipping line 16639: expected 2 fields, saw 3
# Skipping line 16640: expected 2 fields, saw 3

# %%
data = data[['Author','Content']]

# %%
data.sample(6)
# Out:
#                                                Author  \
# 5660                                      h4ckzzd0g55
# 10438  `Access-Control-Allow-Origin: attackersite.com
# 5619                                         windows9
# 7158                                        joemilian
# 10234                                    spaghettisec
# 11305     Sql injection works in GET json requests ?"
#
#                                                  Content
# 5660                                She explains it cool
# 10438                                                NaN
# 5619            i have the $20 option from Digital Ocean
# 7158           I haven't updated since the first release
# 10234  Found a subdomain with this vulnerability shou...
# 11305                                                NaN

# %%
CHARACTER_NAME = 'the discord username of person you want to clone here'

# %%
contexted = []

# context window of size 7
n = 7

for i in data[data.Author == CHARACTER_NAME].index:
  if i < n:
    continue
  row = []
  prev = i - 1 - n # we additionally substract 1, so row will contain current responce and 7 previous responces
  for j in range(i, prev, -1):
    row.append(data.iloc[j]['Content'])
  contexted.append(row)

columns = ['response', 'context']
columns = columns + ['context/' + str(i) for i in range(n - 1)]

df = pd.DataFrame.from_records(contexted, columns=columns)

# %%
df.sample(6)
# Out:
#                                                response  \
# 1044                                               bruh
# 93    "i would actually suggest doing somerhing like...
# 230                                        Why is that?
# 772                               how is it vulnerable?
# 500                                              agreed
# 385   look at the patch and try to figure out what t...
#
#                                                 context  \
# 1044  as long as there is javascript executed there ...
# 93                    just to yolo and see what happens
# 230        but I'm pretty sure I know why he asked that
# 772   You can do this using cut or use awk like `awk...
# 500   on a serious note buying courses and falling f...
# 385       @d0nut  can you please explain me a bit more.
#
#                                               context/0  \
# 1044  Or if it’s a provider like zoom that lets you ...
# 93    "maybe try actual json like `{{""foo"": ""bar"...
# 230                                              I know
# 772                       "Not this ""param pp ....."""
# 500   https://tenor.com/view/no-bugs-bunny-nope-gif-...
# 385                  @<h1>test</h1> reverse engineer it
#
#                                               context/1  \
# 1044                           Subdomain takeover works
# 93    oh very cool. okay so the `{{ ... }}` seems im...
# 230                                    super irrelevant
# 772                                Bro I want only urls
# 500                                       complimentary
# 385   How you can test for CVE 2020-5902 for your ta...
#
#                                               context/2  \
# 1044                                              xss ?
# 93                                                  NaN
# 230                                                 wat
# 772                                                 NaN
# 500                                1 free python script
# 385   Yeah. Reporting something even if out of scope...
#
#                                               context/3  \
# 1044                 It’s not a perfect csrf mitigation
# 93                       "{{ 7 * 7 }}  -> returns blank
# 230              """do you hack only on our program?"""
# 772            "are you getting that link in your mail?
# 500                          @0xatul ? :aPES_LulLaugh:"
# 385   be extra professional in your report and be pr...
#
#                                               context/4  \
# 1044  I posted something but you need another bug to...
# 93                                   yikes i can't type
# 230                                      what question?
# 772                   like if get an email with my host
# 500                                  just saw this haha
# 385   sometimes but i try to make sure it's either p...
#
#                                               context/5
# 1044                         yes i have no idea neither
# 93                                    *create an object
# 230   I've spent so much time on their program and t...
# 772                                                 NaN
# 500   I love to find undocumented stuff. there used ...
# 385                 I feel so bad for the Aditya guy 😂😂

# %%
trn_df, val_df = train_test_split(df, test_size=0.1)
trn_df.head()
# Out:
#                                                response  \
# 126             I think it might be for testing reasons
# 907   perhaps you need to use `cast(versionnumber as...
# 1156                    Dont see a shell == doesnt work
# 137       i could see myself reporting that technically
# 1126  yea you can use that to enumerate email addresses
#
#                                            context  \
# 126                   it's right about that......"
# 907                            But the length is 4
# 1156  Which will force your browser to download it
# 137                                  hmmmmmm maybe
# 1126                         oh that's pretty cool
#
#                                               context/0  \
# 126                                                 NaN
# 907                 it sounds like there isn't a second
# 1156    Also it’s probably a content disposition header
# 137                                           sure dude
# 1126  is there anyway to exploit this like operator ...
#
#                                               context/1  \
# 126                                                 NaN
# 907   im wondering if the version number that came b...
# 1156            So you chose a php webshell originally?
# 137              I can drop post it if you can share it
# 1126                                                NaN
#
#                                               context/2  \
# 126                            i might be able to help"
# 907                                                 NaN
# 1156  well they are running node.js so i did it with...
# 137                                                 rip
# 1126                                         "Hello all
#
#                                               context/3  \
# 126                                                 NaN
# 907                                                 NaN
# 1156                                                etc
# 137   like and comment some posts. it will come in e...
# 1126   just the first yt that seems to explain it co...
#
#                                               context/4  \
# 126                                                 NaN
# 907                                                 NaN
# 1156  can you upload it somewhere along other php fi...
# 137                                             oh well
# 1126   just the ""mean"" of the attack. Some servers...
#
#                                               context/5
# 126                                                 NaN
# 907    to retrieve for 2nd position of any string we...
# 1156                              is your backend php ?
# 137                     i was gonna drop something cool
# 1126                  "CRLF = Carriage Return Line Feed

# %%
# create dataset suitable for our model
def construct_conv(row, tokenizer, eos = True):
    flatten = lambda l: [item for sublist in l for item in sublist]
    conv = []
    for x in row:
      if type(x) == str:
        conv += [tokenizer.encode(x) + [tokenizer.eos_token_id]]
    conv = list(reversed(conv))
    #conv = list(reversed([tokenizer.encode(x) + [tokenizer.eos_token_id] for x in row]))
    conv = flatten(conv)
    return conv

class ConversationDataset(Dataset):
    def __init__(self, tokenizer: PreTrainedTokenizer, args, df, block_size=512):

        block_size = block_size - (tokenizer.model_max_length - tokenizer.max_len_single_sentence)

        directory = args.cache_dir
        cached_features_file = os.path.join(
            directory, args.model_type + "_cached_lm_" + str(block_size)
        )

        if os.path.exists(cached_features_file) and not args.overwrite_cache:
            logger.info("Loading features from cached file %s", cached_features_file)
            with open(cached_features_file, "rb") as handle:
                self.examples = pickle.load(handle)
        else:
            logger.info("Creating features from dataset file at %s", directory)

            self.examples = []
            for _, row in df.iterrows():
                conv = construct_conv(row, tokenizer)
                self.examples.append(conv)

            logger.info("Saving features into cached file %s", cached_features_file)
            with open(cached_features_file, "wb") as handle:
                pickle.dump(self.examples, handle, protocol=pickle.HIGHEST_PROTOCOL)

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, item):
        return torch.tensor(self.examples[item], dtype=torch.long)

# %%
# Cacheing and storing of data/checkpoints

def load_and_cache_examples(args, tokenizer, df_trn, df_val, evaluate=False):
    return ConversationDataset(tokenizer, args, df_val if evaluate else df_trn)


def set_seed(args):
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    if args.n_gpu > 0:
        torch.cuda.manual_seed_all(args.seed)


def _sorted_checkpoints(args, checkpoint_prefix="checkpoint", use_mtime=False) -> List[str]:
    ordering_and_checkpoint_path = []

    glob_checkpoints = glob.glob(os.path.join(args.output_dir, "{}-*".format(checkpoint_prefix)))

    for path in glob_checkpoints:
        if use_mtime:
            ordering_and_checkpoint_path.append((os.path.getmtime(path), path))
        else:
            regex_match = re.match(".*{}-([0-9]+)".format(checkpoint_prefix), path)
            if regex_match and regex_match.groups():
                ordering_and_checkpoint_path.append((int(regex_match.groups()[0]), path))

    checkpoints_sorted = sorted(ordering_and_checkpoint_path)
    checkpoints_sorted = [checkpoint[1] for checkpoint in checkpoints_sorted]
    return checkpoints_sorted


def _rotate_checkpoints(args, checkpoint_prefix="checkpoint", use_mtime=False) -> None:
    if not args.save_total_limit:
        return
    if args.save_total_limit <= 0:
        return

    # Check if we should delete older checkpoint(s)
    checkpoints_sorted = _sorted_checkpoints(args, checkpoint_prefix, use_mtime)
    if len(checkpoints_sorted) <= args.save_total_limit:
        return

    number_of_checkpoints_to_delete = max(0, len(checkpoints_sorted) - args.save_total_limit)
    checkpoints_to_be_deleted = checkpoints_sorted[:number_of_checkpoints_to_delete]
    for checkpoint in checkpoints_to_be_deleted:
        logger.info("Deleting older checkpoint [{}] due to args.save_total_limit".format(checkpoint))
        shutil.rmtree(checkpoint)

# %% [markdown]
# ## Build Model

# %%
from transformers import AutoModelWithLMHead, AutoModelForCausalLM, AutoTokenizer, AutoModelForSeq2SeqLM
import torch

tokenizer = AutoTokenizer.from_pretrained("gpt2")
model = AutoModelForCausalLM.from_pretrained("gpt2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
"""
Fine-tuning the library models for language modeling on a text file (GPT, GPT-2, BERT, RoBERTa).
GPT and GPT-2 are fine-tuned using a causal language modeling (CLM) loss while BERT and RoBERTa are fine-tuned
using a masked language modeling (MLM) loss.
"""

# Configs
logger = logging.getLogger(__name__)

MODEL_CONFIG_CLASSES = list(MODEL_WITH_LM_HEAD_MAPPING.keys())
MODEL_TYPES = tuple(conf.model_type for conf in MODEL_CONFIG_CLASSES)

# %%
# Args to allow for easy convertion of python script to notebook
class Args():
    def __init__(self):
        self.output_dir = 'output-medium'
        self.model_type = 'gpt2'
        self.model_name_or_path = 'microsoft/DialoGPT-medium'
        self.config_name = 'microsoft/DialoGPT-medium'
        self.tokenizer_name = 'microsoft/DialoGPT-medium'
        self.cache_dir = 'cached'
        self.block_size = 512
        self.do_train = True
        self.do_eval = True
        self.evaluate_during_training = False
        self.per_gpu_train_batch_size = 4
        self.per_gpu_eval_batch_size = 4
        self.gradient_accumulation_steps = 1
        self.learning_rate = 5e-5
        self.weight_decay = 0.0
        self.adam_epsilon = 1e-8
        self.max_grad_norm = 1.0
        self.num_train_epochs = 3
        self.max_steps = -1
        self.warmup_steps = 0
        self.logging_steps = 1000
        self.save_steps = 3500
        self.save_total_limit = None
        self.eval_all_checkpoints = False
        self.no_cuda = False
        self.overwrite_output_dir = True
        self.overwrite_cache = True
        self.should_continue = False
        self.seed = 42
        self.local_rank = -1
        self.fp16 = False
        self.fp16_opt_level = 'O1'

args = Args()

# %% [markdown]
# ## Train and Evaluate

# %%
def train(args, train_dataset, model: PreTrainedModel, tokenizer: PreTrainedTokenizer) -> Tuple[int, float]:
    """ Train the model """
    if args.local_rank in [-1, 0]:
        tb_writer = SummaryWriter()

    args.train_batch_size = args.per_gpu_train_batch_size * max(1, args.n_gpu)

    def collate(examples: List[torch.Tensor]):
        if tokenizer._pad_token is None:
            return pad_sequence(examples, batch_first=True)
        return pad_sequence(examples, batch_first=True, padding_value=tokenizer.pad_token_id)

    train_sampler = RandomSampler(train_dataset) if args.local_rank == -1 else DistributedSampler(train_dataset)
    train_dataloader = DataLoader(
        train_dataset, sampler=train_sampler, batch_size=args.train_batch_size, collate_fn=collate, drop_last = True
    )

    if args.max_steps > 0:
        t_total = args.max_steps
        args.num_train_epochs = args.max_steps // (len(train_dataloader) // args.gradient_accumulation_steps) + 1
    else:
        t_total = len(train_dataloader) // args.gradient_accumulation_steps * args.num_train_epochs

    model = model.module if hasattr(model, "module") else model  # Take care of distributed/parallel training
    model.resize_token_embeddings(len(tokenizer))
    # add_special_tokens_(model, tokenizer)


    # Prepare optimizer and schedule (linear warmup and decay)
    no_decay = ["bias", "LayerNorm.weight"]
    optimizer_grouped_parameters = [
        {
            "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
            "weight_decay": args.weight_decay,
        },
        {"params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], "weight_decay": 0.0},
    ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=args.learning_rate, eps=args.adam_epsilon)
    scheduler = get_linear_schedule_with_warmup(
        optimizer, num_warmup_steps=args.warmup_steps, num_training_steps=t_total
    )

    # Check if saved optimizer or scheduler states exist
    if (
        args.model_name_or_path
        and os.path.isfile(os.path.join(args.model_name_or_path, "optimizer.pt"))
        and os.path.isfile(os.path.join(args.model_name_or_path, "scheduler.pt"))
    ):
        # Load in optimizer and scheduler states
        optimizer.load_state_dict(torch.load(os.path.join(args.model_name_or_path, "optimizer.pt")))
        scheduler.load_state_dict(torch.load(os.path.join(args.model_name_or_path, "scheduler.pt")))

    if args.fp16:
        try:
            from apex import amp
        except ImportError:
            raise ImportError("Please install apex from https://www.github.com/nvidia/apex to use fp16 training.")
        model, optimizer = amp.initialize(model, optimizer, opt_level=args.fp16_opt_level)

    # multi-gpu training (should be after apex fp16 initialization)
    if args.n_gpu > 1:
        model = torch.nn.DataParallel(model)

    # Distributed training (should be after apex fp16 initialization)
    if args.local_rank != -1:
        model = torch.nn.parallel.DistributedDataParallel(
            model, device_ids=[args.local_rank], output_device=args.local_rank, find_unused_parameters=True
        )

    # Train!
    logger.info("***** Running training *****")
    logger.info("  Num examples = %d", len(train_dataset))
    logger.info("  Num Epochs = %d", args.num_train_epochs)
    logger.info("  Instantaneous batch size per GPU = %d", args.per_gpu_train_batch_size)
    logger.info(
        "  Total train batch size (w. parallel, distributed & accumulation) = %d",
        args.train_batch_size
        * args.gradient_accumulation_steps
        * (torch.distributed.get_world_size() if args.local_rank != -1 else 1),
    )
    logger.info("  Gradient Accumulation steps = %d", args.gradient_accumulation_steps)
    logger.info("  Total optimization steps = %d", t_total)

    global_step = 0
    epochs_trained = 0
    steps_trained_in_current_epoch = 0
    # Check if continuing training from a checkpoint
    if args.model_name_or_path and os.path.exists(args.model_name_or_path):
        try:
            # set global_step to gobal_step of last saved checkpoint from model path
            checkpoint_suffix = args.model_name_or_path.split("-")[-1].split("/")[0]
            global_step = int(checkpoint_suffix)
            epochs_trained = global_step // (len(train_dataloader) // args.gradient_accumulation_steps)
            steps_trained_in_current_epoch = global_step % (len(train_dataloader) // args.gradient_accumulation_steps)

            logger.info("  Continuing training from checkpoint, will skip to saved global_step")
            logger.info("  Continuing training from epoch %d", epochs_trained)
            logger.info("  Continuing training from global step %d", global_step)
            logger.info("  Will skip the first %d steps in the first epoch", steps_trained_in_current_epoch)
        except ValueError:
            logger.info("  Starting fine-tuning.")

    tr_loss, logging_loss = 0.0, 0.0

    model.zero_grad()
    train_iterator = trange(
        epochs_trained, int(args.num_train_epochs), desc="Epoch", disable=args.local_rank not in [-1, 0]
    )
    set_seed(args)  # Added here for reproducibility
    for _ in train_iterator:
        epoch_iterator = tqdm(train_dataloader, desc="Iteration", disable=args.local_rank not in [-1, 0])
        for step, batch in enumerate(epoch_iterator):

            # Skip past any already trained steps if resuming training
            if steps_trained_in_current_epoch > 0:
                steps_trained_in_current_epoch -= 1
                continue

            inputs, labels = (batch, batch)
            if inputs.shape[1] > 1024: continue
            inputs = inputs.to(args.device)
            labels = labels.to(args.device)
            model.train()
            outputs = model(inputs, labels=labels)
            loss = outputs[0]  # model outputs are always tuple in transformers (see doc)

            if args.n_gpu > 1:
                loss = loss.mean()  # mean() to average on multi-gpu parallel training
            if args.gradient_accumulation_steps > 1:
                loss = loss / args.gradient_accumulation_steps

            if args.fp16:
                with amp.scale_loss(loss, optimizer) as scaled_loss:
                    scaled_loss.backward()
            else:
                loss.backward()

            tr_loss += loss.item()
            if (step + 1) % args.gradient_accumulation_steps == 0:
                if args.fp16:
                    torch.nn.utils.clip_grad_norm_(amp.master_params(optimizer), args.max_grad_norm)
                else:
                    torch.nn.utils.clip_grad_norm_(model.parameters(), args.max_grad_norm)
                optimizer.step()
                scheduler.step()  # Update learning rate schedule
                model.zero_grad()
                global_step += 1

                if args.local_rank in [-1, 0] and args.logging_steps > 0 and global_step % args.logging_steps == 0:
                    # Log metrics
                    if (
                        args.local_rank == -1 and args.evaluate_during_training
                    ):  # Only evaluate when single GPU otherwise metrics may not average well
                        results = evaluate(args, model, tokenizer)
                        for key, value in results.items():
                            tb_writer.add_scalar("eval_{}".format(key), value, global_step)
                    tb_writer.add_scalar("lr", scheduler.get_lr()[0], global_step)
                    tb_writer.add_scalar("loss", (tr_loss - logging_loss) / args.logging_steps, global_step)
                    logging_loss = tr_loss

                if args.local_rank in [-1, 0] and args.save_steps > 0 and global_step % args.save_steps == 0:
                    checkpoint_prefix = "checkpoint"
                    # Save model checkpoint
                    output_dir = os.path.join(args.output_dir, "{}-{}".format(checkpoint_prefix, global_step))
                    os.makedirs(output_dir, exist_ok=True)
                    model_to_save = (
                        model.module if hasattr(model, "module") else model
                    )  # Take care of distributed/parallel training
                    model_to_save.save_pretrained(output_dir)
                    tokenizer.save_pretrained(output_dir)

                    torch.save(args, os.path.join(output_dir, "training_args.bin"))
                    logger.info("Saving model checkpoint to %s", output_dir)

                    _rotate_checkpoints(args, checkpoint_prefix)

                    torch.save(optimizer.state_dict(), os.path.join(output_dir, "optimizer.pt"))
                    torch.save(scheduler.state_dict(), os.path.join(output_dir, "scheduler.pt"))
                    logger.info("Saving optimizer and scheduler states to %s", output_dir)

            if args.max_steps > 0 and global_step > args.max_steps:
                epoch_iterator.close()
                break
        if args.max_steps > 0 and global_step > args.max_steps:
            train_iterator.close()
            break

    if args.local_rank in [-1, 0]:
        tb_writer.close()

    return global_step, tr_loss / global_step

# Evaluation of some model

def evaluate(args, model: PreTrainedModel, tokenizer: PreTrainedTokenizer, df_trn, df_val, prefix="") -> Dict:
    # Loop to handle MNLI double evaluation (matched, mis-matched)
    eval_output_dir = args.output_dir

    eval_dataset = load_and_cache_examples(args, tokenizer, df_trn, df_val, evaluate=True)
    os.makedirs(eval_output_dir, exist_ok=True)
    args.eval_batch_size = args.per_gpu_eval_batch_size * max(1, args.n_gpu)
    # Note that DistributedSampler samples randomly

    def collate(examples: List[torch.Tensor]):
        if tokenizer._pad_token is None:
            return pad_sequence(examples, batch_first=True)
        return pad_sequence(examples, batch_first=True, padding_value=tokenizer.pad_token_id)

    eval_sampler = SequentialSampler(eval_dataset)
    eval_dataloader = DataLoader(
        eval_dataset, sampler=eval_sampler, batch_size=args.eval_batch_size, collate_fn=collate, drop_last = True
    )

    # multi-gpu evaluate
    if args.n_gpu > 1:
        model = torch.nn.DataParallel(model)

    # Eval!
    logger.info("***** Running evaluation {} *****".format(prefix))
    logger.info("  Num examples = %d", len(eval_dataset))
    logger.info("  Batch size = %d", args.eval_batch_size)
    eval_loss = 0.0
    nb_eval_steps = 0
    model.eval()

    for batch in tqdm(eval_dataloader, desc="Evaluating"):
        inputs, labels = (batch, batch)
        inputs = inputs.to(args.device)
        labels = labels.to(args.device)

        with torch.no_grad():
            outputs = model(inputs, labels=labels)
            lm_loss = outputs[0]
            eval_loss += lm_loss.mean().item()
        nb_eval_steps += 1

    eval_loss = eval_loss / nb_eval_steps
    perplexity = torch.exp(torch.tensor(eval_loss))

    result = {"perplexity": perplexity}

    output_eval_file = os.path.join(eval_output_dir, prefix, "eval_results.txt")
    with open(output_eval_file, "w") as writer:
        logger.info("***** Eval results {} *****".format(prefix))
        for key in sorted(result.keys()):
            logger.info("  %s = %s", key, str(result[key]))
            writer.write("%s = %s\n" % (key, str(result[key])))

    return result

# %%
# Main runner

def main(df_trn, df_val):
    args = Args()

    if args.should_continue:
        sorted_checkpoints = _sorted_checkpoints(args)
        if len(sorted_checkpoints) == 0:
            raise ValueError("Used --should_continue but no checkpoint was found in --output_dir.")
        else:
            args.model_name_or_path = sorted_checkpoints[-1]

    if (
        os.path.exists(args.output_dir)
        and os.listdir(args.output_dir)
        and args.do_train
        and not args.overwrite_output_dir
        and not args.should_continue
    ):
        raise ValueError(
            "Output directory ({}) already exists and is not empty. Use --overwrite_output_dir to overcome.".format(
                args.output_dir
            )
        )

    # Setup CUDA, GPU & distributed training
    device = torch.device("cuda")
    args.n_gpu = torch.cuda.device_count()
    args.device = device

    # Setup logging
    logging.basicConfig(
        format="%(asctime)s - %(levelname)s - %(name)s -   %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S",
        level=logging.INFO if args.local_rank in [-1, 0] else logging.WARN,
    )
    logger.warning(
        "Process rank: %s, device: %s, n_gpu: %s, distributed training: %s, 16-bits training: %s",
        args.local_rank,
        device,
        args.n_gpu,
        bool(args.local_rank != -1),
        args.fp16,
    )

    # Set seed
    set_seed(args)

    config = AutoConfig.from_pretrained(args.config_name, cache_dir=args.cache_dir)
    tokenizer = AutoTokenizer.from_pretrained(args.tokenizer_name, cache_dir=args.cache_dir)
    model = AutoModelWithLMHead.from_pretrained(
        args.model_name_or_path,
        from_tf=False,
        config=config,
        cache_dir=args.cache_dir,
    )
    model.to(args.device)

    logger.info("Training/evaluation parameters %s", args)

    # Training
    if args.do_train:
        train_dataset = load_and_cache_examples(args, tokenizer, df_trn, df_val, evaluate=False)

        global_step, tr_loss = train(args, train_dataset, model, tokenizer)
        logger.info(" global_step = %s, average loss = %s", global_step, tr_loss)

    # Saving best-practices: if you use save_pretrained for the model and tokenizer, you can reload them using from_pretrained()
    if args.do_train:
        # Create output directory if needed
        os.makedirs(args.output_dir, exist_ok=True)

        logger.info("Saving model checkpoint to %s", args.output_dir)
        # Save a trained model, configuration and tokenizer using `save_pretrained()`.
        # They can then be reloaded using `from_pretrained()`
        model_to_save = (
            model.module if hasattr(model, "module") else model
        )  # Take care of distributed/parallel training
        model_to_save.save_pretrained(args.output_dir)
        tokenizer.save_pretrained(args.output_dir)

        # Good practice: save your training arguments together with the trained model
        torch.save(args, os.path.join(args.output_dir, "training_args.bin"))

        # Load a trained model and vocabulary that you have fine-tuned
        model = AutoModelWithLMHead.from_pretrained(args.output_dir)
        tokenizer = AutoTokenizer.from_pretrained(args.output_dir)
        model.to(args.device)

    # Evaluation
    results = {}
    if args.do_eval and args.local_rank in [-1, 0]:
        checkpoints = [args.output_dir]
        if args.eval_all_checkpoints:
            checkpoints = list(
                os.path.dirname(c) for c in sorted(glob.glob(args.output_dir + "/**/" + WEIGHTS_NAME, recursive=True))
            )
            logging.getLogger("transformers.modeling_utils").setLevel(logging.WARN)  # Reduce logging
        logger.info("Evaluate the following checkpoints: %s", checkpoints)
        for checkpoint in checkpoints:
            global_step = checkpoint.split("-")[-1] if len(checkpoints) > 1 else ""
            prefix = checkpoint.split("/")[-1] if checkpoint.find("checkpoint") != -1 else ""

            model = AutoModelWithLMHead.from_pretrained(checkpoint)
            model.to(args.device)
            result = evaluate(args, model, tokenizer, df_trn, df_val, prefix=prefix)
            result = dict((k + "_{}".format(global_step), v) for k, v in result.items())
            results.update(result)

    return results

# %% [markdown]
# ## Run the Main Function

# %%
main(trn_df, val_df)
# Out:
# WARNING:__main__:Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1509: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch:   0%|          | 0/3 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/281 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/281 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/281 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1509: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# Evaluating:   0%|          | 0/31 [00:00<?, ?it/s]
# {'perplexity_': tensor(5.7339)}

# %% [markdown]
# ## Load the Trained Model

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2")
model = AutoModelWithLMHead.from_pretrained('output-medium')

# %%
# Let's chat for 5 lines
for step in range(4):
    # encode the new user input, add the eos_token and return a tensor in Pytorch
    new_user_input_ids = tokenizer.encode(input(">> User:") + tokenizer.eos_token, return_tensors='pt')

    # append the new user input tokens to the chat history
    bot_input_ids = torch.cat([chat_history_ids, new_user_input_ids], dim=-1) if step > 0 else new_user_input_ids

    # generated a response while limiting the total chat history to 1000 tokens,
    chat_history_ids = model.generate(
        bot_input_ids, max_length=200,
        pad_token_id=tokenizer.eos_token_id,
        no_repeat_ngram_size=3,
        do_sample=True,
        top_k=100,
        top_p=0.7,
        temperature=0.8
    )

    # pretty print last ouput tokens from bot
    print("You Bot: {}".format(tokenizer.decode(chat_history_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True)))
# Out:
# >> User:hi
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# You Bot: Hello
# >> User:can you write a poem for me
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# You Bot: sure thing
# >> User:ok
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# You Bot: here's an idea: what is the url of the file you want to access?
# >> User:what
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# You Bot: !!!*!!<!!>!!

# %% [markdown]
# ## Push Model to Hugging Face

# %%
# !sudo apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
# !git config --global user.email '' # your email here
# Tip: using the same email as your huggingface.co account will link your commits to your profile
# !git config --global user.name '' # your name here

# %%
MY_MODEL_NAME = '' # your model name here
HUGGINGFACE_API_KEY = '' # your api key here

# %%
model.push_to_hub(MY_MODEL_NAME, use_auth_token=HUGGINGFACE_API_KEY)
tokenizer.push_to_hub(MY_MODEL_NAME, use_auth_token=HUGGINGFACE_API_KEY)
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:43: FutureWarning: Pass token='DialoGPT-medium-kathy' as keyword args. From version 0.7 passing these as positional arguments will result in an error
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:676: FutureWarning: `create_repo` now takes `token` as an optional positional argument. Be sure to adapt your code!
#   FutureWarning,
# Cloning https://huggingface.co/kathywu/DialoGPT-medium-kathy into local empty directory.
# 05/13/2022 00:12:39 - WARNING - huggingface_hub.repository -   Cloning https://huggingface.co/kathywu/DialoGPT-medium-kathy into local empty directory.
# Upload file pytorch_model.bin:   0%|          | 3.33k/1.35G [00:00<?, ?B/s]
# remote: Enforcing permissions...
# remote: Allowed refs: all
# To https://huggingface.co/kathywu/DialoGPT-medium-kathy
#    2ae3386..20ea1ef  main -> main
#
# 05/13/2022 00:34:19 - WARNING - huggingface_hub.repository -   remote: Enforcing permissions...
# remote: Allowed refs: all
# To https://huggingface.co/kathywu/DialoGPT-medium-kathy
#    2ae3386..20ea1ef  main -> main
#
# remote: Enforcing permissions...
# remote: Allowed refs: all
# To https://huggingface.co/kathywu/DialoGPT-medium-kathy
#    20ea1ef..0e15217  main -> main
#
# 05/13/2022 00:34:29 - WARNING - huggingface_hub.repository -   remote: Enforcing permissions...
# remote: Allowed refs: all
# To https://huggingface.co/kathywu/DialoGPT-medium-kathy
#    20ea1ef..0e15217  main -> main
# 'https://huggingface.co/kathywu/DialoGPT-medium-kathy/commit/0e152172601fdd162298e792c06056c13aec2d01'

# %% [markdown]
# ## All Done!
